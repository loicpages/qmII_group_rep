# %% [markdown]
# <a href="https://colab.research.google.com/github/loicpages/qmII_group_rep/blob/main/Southern_Africa_Production_and_Export_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries 
import pylab
import pandas as pd
import numpy as np
from google.colab import files
import io
import matplotlib.pyplot as plt
from functools import reduce
# %matplotlib inline
plt.style.use('ggplot')

# %%
#importing data with pandas 
data_path = '/content/df_final_use.csv'
general_df = pd.read_csv(data_path, encoding ='latin-1', sep=',')
general_df.fillna(0, inplace=True)
general_df
# Out:
#           Country  ...                 Region
# 0     Afghanistan  ...  Central and East Asia
# 1     Afghanistan  ...  Central and East Asia
# 2     Afghanistan  ...  Central and East Asia
# 3     Afghanistan  ...  Central and East Asia
# 4     Afghanistan  ...  Central and East Asia
# ...           ...  ...                    ...
# 2579     Zimbabwe  ...        Southern Africa
# 2580     Zimbabwe  ...        Southern Africa
# 2581     Zimbabwe  ...        Southern Africa
# 2582     Zimbabwe  ...        Southern Africa
# 2583     Zimbabwe  ...        Southern Africa
#
# [2584 rows x 20 columns]

# %%
#scatter plots 
def plot_country(country, feature1, feature2, plot=True, show=True):
  country_feature1= general_df[general_df['Country']==country][feature1]
  df_feature1=pd.DataFrame(country_feature1)  

  country_feature2= general_df[general_df['Country']==country][feature2]
  df_feature2 =pd.DataFrame(country_feature2) 

  merged = df_feature1.merge(df_feature2, left_index=True, right_index=True)

  if plot:
    merged.plot(x=feature1, y=feature2, kind = 'scatter')
    plt.title(country)
  
  #linear regression line 
  x=merged[feature1]
  y=merged[feature2]
  x= x.to_numpy()
  y= y.to_numpy()
  m, b = np.polyfit(x, y, 1)
  if plot:
    plt.plot(x, m*x+b, c='red')
  if show:
    print(country)
    print(m)
    print(b)
  
  #Calculating the R square value for each country 
  temp= np.corrcoef(x,y)
  temp[0,1]**2
  rS2=temp[0,1]**2
  if show:
    print(rS2)

  corr = merged.corr()
  return corr

# %%
#calling the function for every country in Southern Africa - food production and import quantity - all
plot_country('Zimbabwe','Exports (all)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Zambia','Exports (all)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Swaziland','Exports (all)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Namibia','Exports (all)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Mozambique','Exports (all)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Malawi','Exports (all)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Madagascar','Exports (all)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Lesotho','Exports (all)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
# Out:
# Zimbabwe
# 2.3023413847673284
# 1678.3219100688543
# 0.26462789671049225
# Zambia
# 3.454538015818663
# 1416.342626762451
# 0.5769038962468305
# Swaziland
# 2.045730708297203
# 102.82641142508977
# 0.03467698193834905
# Namibia
# 0.9620015911934326
# 168.13044240922895
# 0.06201726668192912
# Mozambique
# 15.630754362658978
# 2333.337046495739
# 0.6029273572079457
# Malawi
# 7.078166670564976
# 2113.602688055716
# 0.28353756185191353
# Madagascar
# -7.495102965562338
# 3042.9887084845077
# 0.011932070926391636
# Lesotho
# -0.43740922746613337
# 163.77223740029726
# 0.0009154229319523918
#                                                     Exports (all)(1000MT)  Production Quantity (Grains & Ce.+ Root Crops)(1000MT)
# Exports (all)(1000MT)                                            1.000000                                          -0.030256
# Production Quantity (Grains & Ce.+ Root Crops)(...              -0.030256                                           1.000000

# %%
#scatter plots - per capita
def plot_country(country, feature1, feature2, plot=True, show=True):
  country_feature1= general_df[general_df['Country']==country][feature1]
  df_feature1=pd.DataFrame(country_feature1)  

  country_feature2= general_df[general_df['Country']==country][feature2]
  df_feature2 =pd.DataFrame(country_feature2) 

  merged = df_feature1.merge(df_feature2, left_index=True, right_index=True)

  if plot:
    merged.plot(x=feature1, y=feature2, kind = 'scatter')
    plt.title(country)
  
  #linear regression line 
  x=merged[feature1]
  y=merged[feature2]
  x= x.to_numpy()
  y= y.to_numpy()
  m, b = np.polyfit(x, y, 1)
  if plot:
    plt.plot(x, m*x+b, c='red')
  if show:
    print(country)
    print(m)
    print(b)
  
  #Calculating the R square value for each country 
  temp= np.corrcoef(x,y)
  temp[0,1]**2
  rS2=temp[0,1]**2
  if show:
    print(rS2)

  corr = merged.corr()
  return corr

# %%
#calling the function for every country in Southern Africa - food production and import quantity - per capita
plot_country('Zimbabwe','Exports (all) per capita (kg/cap/year)','Production Quantity per capita (kg/cap/year)')
plot_country('Zambia','Exports (all) per capita (kg/cap/year)','Production Quantity per capita (kg/cap/year)')
plot_country('Swaziland','Exports (all) per capita (kg/cap/year)','Production Quantity per capita (kg/cap/year)')
plot_country('Namibia','Exports (all) per capita (kg/cap/year)','Production Quantity per capita (kg/cap/year)')
plot_country('Mozambique','Exports (all) per capita (kg/cap/year)','Production Quantity per capita (kg/cap/year)')
plot_country('Malawi','Exports (all) per capita (kg/cap/year)','Production Quantity per capita (kg/cap/year)')
plot_country('Madagascar','Exports (all) per capita (kg/cap/year)','Production Quantity per capita (kg/cap/year)')
plot_country('Lesotho','Exports (all) per capita (kg/cap/year)','Production Quantity per capita (kg/cap/year)')
# Out:
# Zimbabwe
# 3.0256208445587505
# 145.23378204738202
# 0.3655704807344893
# Zambia
# 1.8023470174266265
# 167.70101899933093
# 0.19804521425698948
# Swaziland
# 1.8395750907547381
# 115.02880484877706
# 0.015809307970531816
# Namibia
# -0.37420558864422604
# 106.80176267403922
# 0.013791748638797303
# Mozambique
# 9.134448517233391
# 155.17384988171025
# 0.4845763529791659
# Malawi
# 4.109942219953552
# 207.34166689231103
# 0.282588258784096
# Madagascar
# 6.775097842435482
# 205.4302839089733
# 0.05836883939835627
# Lesotho
# 2.247492888168521
# 89.79466006958627
# 0.027320696431134467
#                                               Exports (all) per capita (kg/cap/year)  Production Quantity per capita (kg/cap/year)
# Exports (all) per capita (kg/cap/year)                                       1.00000                                       0.16529
# Production Quantity per capita (kg/cap/year)                                 0.16529                                       1.00000

# %%
#corelation coefficient - production and export (all) 
countries = ['Zimbabwe', 'Zambia','Swaziland', 'Namibia', 'Mozambique','Malawi', 'Madagascar', 'Lesotho']

feature1= 'Production Quantity per capita (kg/cap/year)'
feature2= 'Exports (all) per capita (kg/cap/year)'

list_of_correlations = []

for country in countries : 
  corr = plot_country(country, feature1, feature2, False, False)
  list_of_correlations.append((country,corr))

for corr in list_of_correlations : 
  print(corr[0], corr[1])
# Out:
# Zimbabwe                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.604624
# Exports (all) per capita (kg/cap/year)                                            0.604624                                1.000000
# Zambia                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.445023
# Exports (all) per capita (kg/cap/year)                                            0.445023                                1.000000
# Swaziland                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.125735
# Exports (all) per capita (kg/cap/year)                                            0.125735                                1.000000
# Namibia                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                               -0.117438
# Exports (all) per capita (kg/cap/year)                                           -0.117438                                1.000000
# Mozambique                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.696115
# Exports (all) per capita (kg/cap/year)                                            0.696115                                1.000000
# Malawi                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                       1.00000                                 0.53159
# Exports (all) per capita (kg/cap/year)                                             0.53159                                 1.00000
# Madagascar                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.241596
# Exports (all) per capita (kg/cap/year)                                            0.241596                                1.000000
# Lesotho                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                       1.00000                                 0.16529
# Exports (all) per capita (kg/cap/year)                                             0.16529                                 1.00000

# %%
#export of grains

# %%
#scatter plots 
def plot_country(country, feature1, feature2, plot=True, show=True):
  country_feature1= general_df[general_df['Country']==country][feature1]
  df_feature1=pd.DataFrame(country_feature1)  

  country_feature2= general_df[general_df['Country']==country][feature2]
  df_feature2 =pd.DataFrame(country_feature2) 

  merged = df_feature1.merge(df_feature2, left_index=True, right_index=True)

  if plot:
    merged.plot(x=feature1, y=feature2, kind = 'scatter')
    plt.title(country)
  
  #linear regression line 
  x=merged[feature1]
  y=merged[feature2]
  x= x.to_numpy()
  y= y.to_numpy()
  m, b = np.polyfit(x, y, 1)
  if plot:
    plt.plot(x, m*x+b, c='red')
  if show:
    print(country)
    print(m)
    print(b)
  
  #Calculating the R square value for each country 
  temp= np.corrcoef(x,y)
  temp[0,1]**2
  rS2=temp[0,1]**2
  if show:
    print(rS2)

  corr = merged.corr()
  return corr

# %%
#calling the function for every country in Southern Africa - food production and grain export
plot_country('Zimbabwe','Export Quantity (Grains & Ce.)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Zambia','Export Quantity (Grains & Ce.)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Swaziland','Export Quantity (Grains & Ce.)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Namibia','Export Quantity (Grains & Ce.)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Mozambique','Export Quantity (Grains & Ce.)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Malawi','Export Quantity (Grains & Ce.)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Madagascar','Export Quantity (Grains & Ce.)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Lesotho','Export Quantity (Grains & Ce.)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
# Out:
# Zimbabwe
# 2.3030738901387484
# 1679.2141908750352
# 0.2651363750801695
# Zambia
# 3.5278881469731194
# 1357.817198205263
# 0.6891416424673376
# Swaziland
# 2.8055869796388353
# 103.79337667549666
# 0.07132514019695188
# Namibia
# 0.8939865139144137
# 168.71059222137094
# 0.05072109419562165
# Mozambique
# 15.674544175810471
# 2321.5899122816677
# 0.5994596937499662
# Malawi
# 7.351157635610115
# 2085.242709163952
# 0.3023441840269836
# Madagascar
# -5.614978350581116
# 3018.251493151377
# 0.004812961948055425
# Lesotho
# -0.43740922746613337
# 163.77223740029726
# 0.0009154229319523918
#                                                     Export Quantity (Grains & Ce.)(1000MT)  Production Quantity (Grains & Ce.+ Root Crops)(1000MT)
# Export Quantity (Grains & Ce.)(1000MT)                                            1.000000                                          -0.030256
# Production Quantity (Grains & Ce.+ Root Crops)(...                               -0.030256                                           1.000000

# %%
#correlation coefficient - production and export (grains)
countries = ['Zimbabwe', 'Zambia','Swaziland', 'Namibia', 'Mozambique','Malawi', 'Madagascar', 'Lesotho']

feature1= 'Production Quantity per capita (kg/cap/year)'
feature2= 'Exports (all) per capita (kg/cap/year)'

list_of_correlations = []

for country in countries : 
  corr = plot_country(country, feature1, feature2, False, False)
  list_of_correlations.append((country,corr))

for corr in list_of_correlations : 
  print(corr[0], corr[1])
# Out:
# Zimbabwe                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.604624
# Exports (all) per capita (kg/cap/year)                                            0.604624                                1.000000
# Zambia                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.445023
# Exports (all) per capita (kg/cap/year)                                            0.445023                                1.000000
# Swaziland                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.125735
# Exports (all) per capita (kg/cap/year)                                            0.125735                                1.000000
# Namibia                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                               -0.117438
# Exports (all) per capita (kg/cap/year)                                           -0.117438                                1.000000
# Mozambique                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.696115
# Exports (all) per capita (kg/cap/year)                                            0.696115                                1.000000
# Malawi                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                       1.00000                                 0.53159
# Exports (all) per capita (kg/cap/year)                                             0.53159                                 1.00000
# Madagascar                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                      1.000000                                0.241596
# Exports (all) per capita (kg/cap/year)                                            0.241596                                1.000000
# Lesotho                                               Production Quantity per capita (kg/cap/year)  Exports (all) per capita (kg/cap/year)
# Production Quantity per capita (kg/cap/year)                                       1.00000                                 0.16529
# Exports (all) per capita (kg/cap/year)                                             0.16529                                 1.00000

# %% [markdown]
# Production and Export of Root Crops

# %%
#scatter plots
general_df.fillna(0, inplace=True)
def plot_country(country, feature1, feature2, plot=True, show=True):
  country_feature1= general_df[general_df['Country']==country][feature1]
  df_feature1=pd.DataFrame(country_feature1)  

  country_feature2= general_df[general_df['Country']==country][feature2]
  df_feature2 =pd.DataFrame(country_feature2) 

  merged = df_feature1.merge(df_feature2, left_index=True, right_index=True)

  if plot:
    merged.plot(x=feature1, y=feature2, kind = 'scatter')
    plt.title(country)
  
  #linear regression line 
  x=merged[feature1]
  y=merged[feature2]
  x= x.to_numpy()
  y= y.to_numpy()
  m, b = np.polyfit(x, y, 1)
  if plot:
    plt.plot(x, m*x+b, c='red')
  if show:
    print(country)
    print(m)
    print(b)
  
  #Calculating the R square value for each country 
  temp= np.corrcoef(x,y)
  temp[0,1]**2
  rS2=temp[0,1]**2
  if show:
    print(rS2)

  corr = merged.corr()
  return corr

# %%
#calling the function for every country in Southern Africa - food production and grain export
plot_country('Zimbabwe','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Zambia','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Swaziland','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Namibia','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Mozambique','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Malawi','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Madagascar','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
plot_country('Lesotho','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
# Out:
# Zimbabwe
# -265.8668659092818
# 2109.628308279953
# 0.04897948960502508
# Zambia
# 23.992059959271298
# 1754.2496933278665
# 0.00019010326534740378
# Swaziland
# -5.746588204150423
# 114.48684265414275
# 0.048682997304345964
# Namibia
# 24.524611365299528
# 169.8302328182989
# 0.07035476698514766
# Mozambique
# 1717026.1147690013
# 2447.017194403455
# 0.6427019693186897
# Malawi
# -631.7645503662814
# 2806.9723537817813
# 0.07443765586909173
# Madagascar
# -66.9803120983418
# 3058.8186466227585
# 0.04921830069600015
# /usr/local/lib/python3.6/dist-packages/numpy/lib/polynomial.py:628: RuntimeWarning: invalid value encountered in true_divide
#   lhs /= scale
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-7a04a2cfac98> in <module>()
#       7 plot_country('Malawi','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
#       8 plot_country('Madagascar','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
# ----> 9 plot_country('Lesotho','Export Quantity (Root Crops)(1000MT)','Production Quantity (Grains & Ce.+ Root Crops)(1000MT)')
#
# <ipython-input-14-17c6ca3011f3> in plot_country(country, feature1, feature2, plot, show)
#      19   x= x.to_numpy()
#      20   y= y.to_numpy()
# ---> 21   m, b = np.polyfit(x, y, 1)
#      22   if plot:
#      23     plt.plot(x, m*x+b, c='red')
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     627     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     628     lhs /= scale
# --> 629     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     630     c = (c.T/scale).T  # broadcast scale coefficients
#     631
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2304         # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2305         b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2306     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2307     if m == 0:
#    2308         x[...] = 0
#
# ValueError: On entry to DLASCL parameter number 4 had an illegal value

# %% [markdown]
# <a href="https://colab.research.google.com/github/loicpages/qmII_group_rep/blob/main/Final_Political_events_Southern_Africa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pylab
import pandas as pd
import numpy as np
from google.colab import files
import io
import matplotlib.pyplot as plt
from functools import reduce
import pandas as pd
import altair as alt
# %matplotlib inline
plt.style.use('ggplot')
from  vega_datasets  import  data

# %%
data_path = '/content/df_final_use.csv'
general_df = pd.read_csv(data_path, encoding ='latin-1')

# %% [markdown]
# New dataframe which includes all the countries from Southern Africa and shows the evolution of food availability for each country.

# %%
southern_africa_df= general_df[["Country","Year","Food Availibility per capita (kg/cap/year)","Region","Production Quantity per capita (kg/cap/year)","Exports (all) per capita (kg/cap/year)","Imports (all) per capita (kg/cap/year)","Total Food Aid per capita (kg/cap/year)"]]
southern_africa_df= southern_africa_df[southern_africa_df['Region']=='Southern Africa']
final_southern_africa_df= southern_africa_df[['Country','Food Availibility per capita (kg/cap/year)',"Production Quantity per capita (kg/cap/year)","Exports (all) per capita (kg/cap/year)","Imports (all) per capita (kg/cap/year)","Total Food Aid per capita (kg/cap/year)"]]

# %% [markdown]
# Dataframes for each country from this region.

# %%
lesotho_df=final_southern_africa_df[final_southern_africa_df['Country']=='Lesotho']
madagascar_df=final_southern_africa_df[final_southern_africa_df['Country']=='Madagascar']
malawi_df=final_southern_africa_df[final_southern_africa_df['Country']=='Malawi']
mozambique_df=final_southern_africa_df[final_southern_africa_df['Country']=='Mozambique']
namibia_df=final_southern_africa_df[final_southern_africa_df['Country']=='Namibia']
swaziland_df=final_southern_africa_df[final_southern_africa_df['Country']=='Swaziland']
zambia_df=final_southern_africa_df[final_southern_africa_df['Country']=='Zambia']
zimbabwe_df=final_southern_africa_df[final_southern_africa_df['Country']=='Zimbabwe']

# %% [markdown]
# New dataframes which contain all the political events by year and food aivalibility for each country.

# %%
pol_events_lesotho=pd.DataFrame(['1980','1981','1982','1983','1984','1985','1986 : Overthrow of the authoritarian regime of Leabua Jonathan - start of military regime for 7 years duration','1987','1988','1989','1990','1991','1992','1993 : Multi-party elections, first free elections in 23 years','1994','1995','1996','1997','1998 : Legislative elections leading to political tensions and civil violence (more than 1000 deaths)','1999','2000','2001','2002 : New type of legislative elections, end of political tensions','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013'])
pol_events_lesotho.columns=['Political events']
pol_events_lesotho.index= [1326,1327,1328,1329,1330,1331,1332,1333,1334,1335,1336,1337,1338,1339,1340,1341,1342,1343,1344,1345,1346,1347,1348,1349,1350,1351,1352,1353,1354,1355,1356,1357,1358,1359]
lesotho_final = pd.concat([lesotho_df, pol_events_lesotho], axis=1)

# %%
pol_events_Madagascar=pd.DataFrame(['1980','1981','1982','1983','1984 : Kung fu riots, military intervention','1985','1986','1987','1988','1989','1990','1991 : popular protest','1992','1993 : Election of Albert Zafy as president of madagascar','1994','1995','1996','1997 : Start of economic growth','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009 : Overthrow of Malagasy President Marc Ravalomanana','2010','2011','2012','2013'])
pol_events_Madagascar.columns=['Political events']
pol_events_Madagascar.index= [1394,1395,1396,1397,1398,1399,1400,1401,1402,1403,1404,1405,1406,1407,1408,1409,1410,1411,1412,1413,1414,1415,1416,1417,1418,1419,1420,1421,1422,1423,1424,1425,1426,1427]
Madagascar_final = pd.concat([madagascar_df, pol_events_Madagascar], axis=1)

# %%
pol_events_Malawi=pd.DataFrame(['1980 : Authoritarian regime','1981 : Authoritarian regime','1982 : Authoritarian regime','1983 : Authoritarian regime','1984 : Authoritarian regime','1985 : Authoritarian regime','1986 : Authoritarian regime','1987 : Authoritarian regime','1988 : Authoritarian regime','1989 : Authoritarian regime','1990 : Authoritarian regime','1991','1992','1993','1994 : Election of Bakili Muluzi as President of Malawi, end of a 30-year one-party regime, strat of a democratic regime','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013'])
pol_events_Malawi.columns=['Political events']
pol_events_Malawi.index= [1428,1429,1430,1431,1432,1433,1434,1435,1436,1437,1438,1439,1440,1441,1442,1443,1444,1445,1446,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461]
Malawi_final = pd.concat([malawi_df, pol_events_Malawi], axis=1)

# %%
pol_events_Mozambique=pd.DataFrame(['1980 : Civil war','1981 : Civil war','1982 : Civil war','1983 : Civil war','1984 : Civil war','1985 : Civil war','1986 : Civil war','1987 : Civil war','1988 : Civil war','1989 : Civil war','1990 : Civil war','1991 : Civil war','1992 : End of the civil war','1993','1994 : first democratic election - election of Joachim Chissano','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005 : Armando Guebuza is elected president','2006','2007','2008','2009','2010','2011','2012','2013'])
pol_events_Mozambique.columns=['Political events']
pol_events_Mozambique.index= [1632,1633,1634,1635,1636,1637,1638,1639,1640,1641,1642,1643,1644,1645,1646,1647,1648,1649,1650,1651,1652,1653,1654,1655,1656,1657,1658,1659,1660,1661,1662,1663,1664,1665]
Mozambique_final = pd.concat([mozambique_df, pol_events_Mozambique], axis=1)

# %%
pol_events_Namibia=pd.DataFrame(['1980 : First government of South West Africa/Namibia','1981','1982','1983 : The National Assembly is dissolved','1984','1985 : Intermediate government set up by south africa','1986','1987','1988','1989','1990','1991 : Namibia Declaration of Independence','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005 : Hifikepunye Pohamba is elected president','2006','2007','2008','2009','2010','2011','2012','2013'])
pol_events_Namibia.columns=['Political events']
pol_events_Namibia.index= [1666,1667,1668,1669,1670,1671,1672,1673,1674,1675,1676,1677,1678,1679,1680,1681,1682,1683,1684,1685,1686,1687,1688,1689,1690,1691,1692,1693,1694,1695,1696,1697,1698,1699]
Namibia_final = pd.concat([namibia_df, pol_events_Namibia], axis=1)

# %%
pol_events_Swaziland=pd.DataFrame(['1980','1981','1982 : Death of King Sobhuza II - end of one of the world longest sovereign regimes ','1983','1984','1985','1986 : Mswati III becomes absolute monarch','1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005 : adoption of a first constitution by the swazis','2006 : entry into force of the constitution','2007','2008','2009','2010','2011','2012','2013'])
pol_events_Swaziland.columns=['Political events']
pol_events_Swaziland.index= [2176,2177,2178,2179,2180,2181,2182,2183,2184,2185,2186,2187,2188,2189,2190,2191,2192,2193,2194,2195,2196,2197,2198,2199,2200,2201,2202,2203,2204,2205,2206,2207,2208,2209]
Swaziland_final = pd.concat([swaziland_df, pol_events_Swaziland], axis=1)

# %%
pol_events_Zambia=pd.DataFrame(['1980 : Challenges against Kenneth Kaunda regime (single party)','1981 : Challenges against Kenneth Kaunda regime (single party)','1982 : Challenges against Kenneth Kaunda regime (single party)','1983 : Challenges against Kenneth Kaunda regime (single party)','1984 : Challenges against Kenneth Kaunda regime (single party)','1985 : Challenges against Kenneth Kaunda regime (single party)','1986 : Challenges against Kenneth Kaunda regime (single party)','1987 : Challenges against Kenneth Kaunda regime (single party)','1988 : Challenges against Kenneth Kaunda regime (single party)','1989 : Challenges against Kenneth Kaunda regime (single party)','1990 : Challenges against Kenneth Kaunda regime (single party)','1991 : First multi-party elections, election of Frederick Chiluba as president ','1992 : beginning of a liberal policy','1993 : Liberal policy','1994 : Liberal policy','1995 : Liberal policy','1996 : Liberal policy','1997 : Liberal policy','1998 : Liberal policy','1999 : Liberal policy','2000 : Liberal policy','2001 : Liberal policy','2002 : Famine','2003 : Liberal policy','2004 : Liberal policy','2005 : Liberal policy','2006 : Liberal policy','2007 : Liberal policy','2008 : Liberal policy','2009 : Liberal policy','2010 : Liberal policy','2011 : Liberal policy','2012 : Liberal policy','2013 : Liberal policy'])
pol_events_Zambia.columns=['Political events']
pol_events_Zambia.index= [2516,2517,2518,2519,2520,2521,2522,2523,2524,2525,2526,2527,2528,2529,2530,2531,2532,2533,2534,2535,2536,2537,2538,2539,2540,2541,2542,2543,2544,2545,2546,2547,2548,2549]
Zambia_final = pd.concat([zambia_df, pol_events_Zambia], axis=1)

# %%
pol_events_Zimbabwe=pd.DataFrame(['1980 : Proclamation of independence after several years of civil war','1981','1982','1983','1984','1985','1986','1987 : Robert Mugabe becomes president - authoritarian regime','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008 : legislative and presidential elections - the democratic movement becomes a majority in the assembly','2009 : inflationary explosion - economic chaos','2010','2011','2012','2013'])
pol_events_Zimbabwe.columns=['Political events']
pol_events_Zimbabwe.index= [2550,2551,2552,2553,2554,2555,2556,2557,2558,2559,2560,2561,2562,2563,2564,2565,2566,2567,2568,2569,2570,2571,2572,2573,2574,2575,2576,2577,2578,2579,2580,2581,2582,2583]
Zimbabwe_final = pd.concat([zimbabwe_df, pol_events_Zimbabwe], axis=1)

# %% [markdown]
# Plotting the evolution of food availibility over year  on  a graph which shows all the political events for each country.

# %%
Lesotho = [
      {"year": "1980", "Food availibility per capita (kg/cap/year)": 197.996871,"Production Quantity per capita (kg/cap/year)":151.565996,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":82.657244,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1981", "Food availibility per capita (kg/cap/year)": 202.423694,"Production Quantity per capita (kg/cap/year)":130.673438,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":78.675814,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1982", "Food availibility per capita (kg/cap/year)": 193.041706,"Production Quantity per capita (kg/cap/year)":93.594947,"Exports (all) per capita (kg/cap/year)":5.170043,"Imports (all) per capita (kg/cap/year)":70.337227,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1983", "Food availibility per capita (kg/cap/year)": 201.475150,"Production Quantity per capita (kg/cap/year)":90.253788,"Exports (all) per capita (kg/cap/year)":11.040903,"Imports (all) per capita (kg/cap/year)":104.680833,"Total Food Aid per capita (kg/cap/year)":0.0 },
      {"year": "1984", "Food availibility per capita (kg/cap/year)": 197.231876,"Production Quantity per capita (kg/cap/year)":94.461536,"Exports (all) per capita (kg/cap/year)":2.895389,"Imports (all) per capita (kg/cap/year)":89.799775,"Total Food Aid per capita (kg/cap/year)": 0.0},
      {"year": "1985", "Food availibility per capita (kg/cap/year)": 210.156059,"Production Quantity per capita (kg/cap/year)":116.508080,"Exports (all) per capita (kg/cap/year)":2.809011,"Imports (all) per capita (kg/cap/year)":52.832396,"Total Food Aid per capita (kg/cap/year)":0.0 },
      {"year": "1986", "Food availibility per capita (kg/cap/year)": 208.260873,"Production Quantity per capita (kg/cap/year)":91.553621,"Exports (all) per capita (kg/cap/year)":3.657670,"Imports (all) per capita (kg/cap/year)":76.210892,"Total Food Aid per capita (kg/cap/year)": 0.0},
      {"year": "1987", "Food availibility per capita (kg/cap/year)": 202.994931,"Production Quantity per capita (kg/cap/year)":99.275601,"Exports (all) per capita (kg/cap/year)":8.781935,"Imports (all) per capita (kg/cap/year)":47.678981,"Total Food Aid per capita (kg/cap/year)": 0.0},
      {"year": "1988", "Food availibility per capita (kg/cap/year)": 201.991740,"Production Quantity per capita (kg/cap/year)":153.234049,"Exports (all) per capita (kg/cap/year)":4.571519,"Imports (all) per capita (kg/cap/year)":91.891654,"Total Food Aid per capita (kg/cap/year)":31.152341},
      {"year": "1989", "Food availibility per capita (kg/cap/year)": 205.993724,"Production Quantity per capita (kg/cap/year)":130.002316,"Exports (all) per capita (kg/cap/year)":4.143567,"Imports (all) per capita (kg/cap/year)":120.663661,"Total Food Aid per capita (kg/cap/year)":18.770967},
      {"year": "1990", "Food availibility per capita (kg/cap/year)": 190.520875,"Production Quantity per capita (kg/cap/year)":154.315016,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":132.698522,"Total Food Aid per capita (kg/cap/year)":27.758887},
      {"year": "1991", "Food availibility per capita (kg/cap/year)": 190.503500,"Production Quantity per capita (kg/cap/year)":46.080189,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":140.978157,"Total Food Aid per capita (kg/cap/year)":17.331734},
      {"year": "1992", "Food availibility per capita (kg/cap/year)": 193.248624,"Production Quantity per capita (kg/cap/year)":61.245100,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":152.233032,"Total Food Aid per capita (kg/cap/year)":22.342819},
      {"year": "1993", "Food availibility per capita (kg/cap/year)": 197.062710,"Production Quantity per capita (kg/cap/year)":95.464775,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":140.256796,"Total Food Aid per capita (kg/cap/year)":34.844081},
      {"year": "1994", "Food availibility per capita (kg/cap/year)": 200.253190,"Production Quantity per capita (kg/cap/year)":134.790853,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":107.072005,"Total Food Aid per capita (kg/cap/year)":21.330497},
      {"year": "1995", "Food availibility per capita (kg/cap/year)": 198.524028,"Production Quantity per capita (kg/cap/year)":53.711077,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":145.763214,"Total Food Aid per capita (kg/cap/year)":19.854141},
      {"year": "1996", "Food availibility per capita (kg/cap/year)": 199.640781,"Production Quantity per capita (kg/cap/year)":148.699073,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":84.544911,"Total Food Aid per capita (kg/cap/year)":24.310929},
      {"year": "1997", "Food availibility per capita (kg/cap/year)": 170.009046,"Production Quantity per capita (kg/cap/year)":118.675696,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":77.551216,"Total Food Aid per capita (kg/cap/year)":4.961326},
      {"year": "1998", "Food availibility per capita (kg/cap/year)": 182.064144,"Production Quantity per capita (kg/cap/year)":113.349298,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":102.913451,"Total Food Aid per capita (kg/cap/year)":8.485494},
      {"year": "1999", "Food availibility per capita (kg/cap/year)": 174.599540,"Production Quantity per capita (kg/cap/year)":90.628555,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":90.283952,"Total Food Aid per capita (kg/cap/year)":3.309197},
      {"year": "2000", "Food availibility per capita (kg/cap/year)": 190.779771,"Production Quantity per capita (kg/cap/year)":115.795352,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":96.541755,"Total Food Aid per capita (kg/cap/year)":3.751917},
      {"year": "2001", "Food availibility per capita (kg/cap/year)": 176.674074,"Production Quantity per capita (kg/cap/year)":92.436721,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":82.767868,"Total Food Aid per capita (kg/cap/year)":1.676715},
      {"year": "2002", "Food availibility per capita (kg/cap/year)": 205.391258,"Production Quantity per capita (kg/cap/year)":133.146028,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":93.842600,"Total Food Aid per capita (kg/cap/year)":31.196656},
      {"year": "2003", "Food availibility per capita (kg/cap/year)": 193.019098,"Production Quantity per capita (kg/cap/year)":98.297897,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":104.557791,"Total Food Aid per capita (kg/cap/year)":14.630229},
      {"year": "2004", "Food availibility per capita (kg/cap/year)": 174.964110,"Production Quantity per capita (kg/cap/year)":62.584174,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":99.961629,"Total Food Aid per capita (kg/cap/year)":23.242655},
      {"year": "2005", "Food availibility per capita (kg/cap/year)": 172.891474,"Production Quantity per capita (kg/cap/year)":59.373092,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":103.890192,"Total Food Aid per capita (kg/cap/year)":22.249901},
      {"year": "2006", "Food availibility per capita (kg/cap/year)": 146.482077,"Production Quantity per capita (kg/cap/year)":59.298968,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":91.668072,"Total Food Aid per capita (kg/cap/year)":12.502268},
      {"year": "2007", "Food availibility per capita (kg/cap/year)": 142.319852,"Production Quantity per capita (kg/cap/year)":42.560015,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":111.230852,"Total Food Aid per capita (kg/cap/year)":19.819464},
      {"year": "2008", "Food availibility per capita (kg/cap/year)": 139.198946,"Production Quantity per capita (kg/cap/year)":43.807464,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":98.323893,"Total Food Aid per capita (kg/cap/year)":8.981008},
      {"year": "2009", "Food availibility per capita (kg/cap/year)": 144.691856,"Production Quantity per capita (kg/cap/year)":42.914401,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":108.684389,"Total Food Aid per capita (kg/cap/year)":4.762190},
      {"year": "2010", "Food availibility per capita (kg/cap/year)": 146.429676,"Production Quantity per capita (kg/cap/year)":89.163174,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":98.874138,"Total Food Aid per capita (kg/cap/year)":3.853125},
      {"year": "2011", "Food availibility per capita (kg/cap/year)": 147.272747,"Production Quantity per capita (kg/cap/year)":58.014507,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":109.919213,"Total Food Aid per capita (kg/cap/year)":5.834538},
      {"year": "2012", "Food availibility per capita (kg/cap/year)": 146.758787,"Production Quantity per capita (kg/cap/year)":37.226727,"Exports (all) per capita (kg/cap/year)":0.000000,"Imports (all) per capita (kg/cap/year)":117.349009,"Total Food Aid per capita (kg/cap/year)":8.330238},
      {"year": "2013", "Food availibility per capita (kg/cap/year)": 146.207426,"Production Quantity per capita (kg/cap/year)":47.116518,"Exports (all) per capita (kg/cap/year)": 0.0,"Imports (all) per capita (kg/cap/year)":117.349009 ,"Total Food Aid per capita (kg/cap/year)":8.330238 }
    ]

Events = [{"start":"1997","end":"1997","Legend":"Total Food Aid per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Imports (all) per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Production Quantity per capita(kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Exports (all) per capita (kg/cap/year)"},{"start": "1986","end": "1993","Legend": "Military regime for 7 years duration"},{"start": "1993","end": "1994","Legend": "First free elections in 23 years"},{"start":"1998","end":"1999","Legend":"Political tensions and civil violence (more than 1000 deaths)"},{"start":"2002","end":"2003","Legend":"End of political tensions"},{"start":"1999","end":"1999","Legend":"Food availibility per capita (kg/cap/year)"}]


Lesotho = alt.pd.DataFrame(Lesotho)
Events = alt.pd.DataFrame(Events)

line1 = alt.Chart(Lesotho).mark_line(color='aqua').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Food availibility per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line2 = alt.Chart(Lesotho).mark_line(color='pink').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Production Quantity per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line3 = alt.Chart(Lesotho).mark_line(color='orange').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Exports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line4 = alt.Chart(Lesotho).mark_line(color='green').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Imports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line5 = alt.Chart(Lesotho).mark_line(color='brown').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y',title='Year')),
    alt.Y("Total Food Aid per capita (kg/cap/year)", axis=alt.Axis(title='kg/cap/year'))
).properties(
    width=500,
    height=300
)


rect = alt.Chart(Events).mark_rect().encode(
    x='start:T',
    x2='end:T',
    color='Legend:N'
)






rect + line1 + line2 + line3 +line4 + line5
# Out:
# alt.LayerChart(...)

# %%
Madagascar = [
      {"year": "1980", "Food availibility per capita (kg/cap/year)": 184.226755,"Production Quantity per capita (kg/cap/year)":245.397051,"Exports (all) per capita (kg/cap/year)":0.341178,"Imports (all) per capita (kg/cap/year)":12.791962,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1981", "Food availibility per capita (kg/cap/year)": 187.151250,"Production Quantity per capita (kg/cap/year)":231.913056,"Exports (all) per capita (kg/cap/year)":0.359620,"Imports (all) per capita (kg/cap/year)":31.629726,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1982", "Food availibility per capita (kg/cap/year)": 171.273137,"Production Quantity per capita (kg/cap/year)":225.784689,"Exports (all) per capita (kg/cap/year)":0.250330,"Imports (all) per capita (kg/cap/year)":43.195695,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1983", "Food availibility per capita (kg/cap/year)": 188.991616,"Production Quantity per capita (kg/cap/year)":241.698697,"Exports (all) per capita (kg/cap/year)":0.012696,"Imports (all) per capita (kg/cap/year)":28.484930,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1984", "Food availibility per capita (kg/cap/year)": 188.308895,"Production Quantity per capita (kg/cap/year)":239.346028,"Exports (all) per capita (kg/cap/year)":0.807030,"Imports (all) per capita (kg/cap/year)":17.051049,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1985", "Food availibility per capita (kg/cap/year)": 188.084513,"Production Quantity per capita (kg/cap/year)":237.888647,"Exports (all) per capita (kg/cap/year)":0.133523,"Imports (all) per capita (kg/cap/year)":19.942259,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1986", "Food availibility per capita (kg/cap/year)": 188.377744,"Production Quantity per capita (kg/cap/year)":243.742877,"Exports (all) per capita (kg/cap/year)":0.024965,"Imports (all) per capita (kg/cap/year)":21.554848,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1987", "Food availibility per capita (kg/cap/year)": 180.141340,"Production Quantity per capita (kg/cap/year)":229.102906,"Exports (all) per capita (kg/cap/year)":0.770529,"Imports (all) per capita (kg/cap/year)":17.189072,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1988", "Food availibility per capita (kg/cap/year)": 170.412200,"Production Quantity per capita (kg/cap/year)":221.719020,"Exports (all) per capita (kg/cap/year)":2.088961,"Imports (all) per capita (kg/cap/year)":8.118609,"Total Food Aid per capita (kg/cap/year)":8.026397},
      {"year": "1989", "Food availibility per capita (kg/cap/year)": 171.191407,"Production Quantity per capita (kg/cap/year)":231.519592,"Exports (all) per capita (kg/cap/year)":2.013346,"Imports (all) per capita (kg/cap/year)":11.246668,"Total Food Aid per capita (kg/cap/year)":7.458180},
      {"year": "1990", "Food availibility per capita (kg/cap/year)": 201.503271,"Production Quantity per capita (kg/cap/year)":232.177889,"Exports (all) per capita (kg/cap/year)":1.661755,"Imports (all) per capita (kg/cap/year)":8.067298,"Total Food Aid per capita (kg/cap/year)":5.726493},
      {"year": "1991", "Food availibility per capita (kg/cap/year)": 190.692285,"Production Quantity per capita (kg/cap/year)":220.473313,"Exports (all) per capita (kg/cap/year)":2.075615,"Imports (all) per capita (kg/cap/year)":12.176233,"Total Food Aid per capita (kg/cap/year)":2.815693},
      {"year": "1992", "Food availibility per capita (kg/cap/year)": 190.611546,"Production Quantity per capita (kg/cap/year)":218.167780,"Exports (all) per capita (kg/cap/year)":0.837526,"Imports (all) per capita (kg/cap/year)":7.441946,"Total Food Aid per capita (kg/cap/year)":6.465837},
      {"year": "1993", "Food availibility per capita (kg/cap/year)": 190.223108,"Production Quantity per capita (kg/cap/year)":223.377350,"Exports (all) per capita (kg/cap/year)":2.917255,"Imports (all) per capita (kg/cap/year)":12.138678,"Total Food Aid per capita (kg/cap/year)":3.106329},
      {"year": "1994", "Food availibility per capita (kg/cap/year)": 189.467723,"Production Quantity per capita (kg/cap/year)":206.569287,"Exports (all) per capita (kg/cap/year)":3.094564,"Imports (all) per capita (kg/cap/year)":14.244186,"Total Food Aid per capita (kg/cap/year)":2.180822},
      {"year": "1995", "Food availibility per capita (kg/cap/year)": 184.402471,"Production Quantity per capita (kg/cap/year)":205.306257,"Exports (all) per capita (kg/cap/year)":2.189363,"Imports (all) per capita (kg/cap/year)":6.888662,"Total Food Aid per capita (kg/cap/year)":2.941062},
      {"year": "1996", "Food availibility per capita (kg/cap/year)": 180.683333,"Production Quantity per capita (kg/cap/year)":200.536149,"Exports (all) per capita (kg/cap/year)":1.642821,"Imports (all) per capita (kg/cap/year)":10.817449,"Total Food Aid per capita (kg/cap/year)":1.713178},
      {"year": "1997", "Food availibility per capita (kg/cap/year)": 181.007763,"Production Quantity per capita (kg/cap/year)":197.887525,"Exports (all) per capita (kg/cap/year)":0.071558,"Imports (all) per capita (kg/cap/year)":12.286886,"Total Food Aid per capita (kg/cap/year)":2.470169},
      {"year": "1998", "Food availibility per capita (kg/cap/year)": 164.449290,"Production Quantity per capita (kg/cap/year)":184.792628,"Exports (all) per capita (kg/cap/year)":0.069313,"Imports (all) per capita (kg/cap/year)":19.668654,"Total Food Aid per capita (kg/cap/year)":2.709703},
      {"year": "1999", "Food availibility per capita (kg/cap/year)": 172.377551,"Production Quantity per capita (kg/cap/year)":187.316014,"Exports (all) per capita (kg/cap/year)":0.693124,"Imports (all) per capita (kg/cap/year)":26.437614,"Total Food Aid per capita (kg/cap/year)":3.117652},
      {"year": "2000", "Food availibility per capita (kg/cap/year)": 173.907210,"Production Quantity per capita (kg/cap/year)":177.090587,"Exports (all) per capita (kg/cap/year)":0.020418,"Imports (all) per capita (kg/cap/year)":23.232264,"Total Food Aid per capita (kg/cap/year)":5.928432},
      {"year": "2001", "Food availibility per capita (kg/cap/year)": 171.888012,"Production Quantity per capita (kg/cap/year)":181.069933,"Exports (all) per capita (kg/cap/year)":0.025787,"Imports (all) per capita (kg/cap/year)":19.314538,"Total Food Aid per capita (kg/cap/year)":5.645711},
      {"year": "2002", "Food availibility per capita (kg/cap/year)": 166.287884,"Production Quantity per capita (kg/cap/year)":169.376353,"Exports (all) per capita (kg/cap/year)":0.026311,"Imports (all) per capita (kg/cap/year)":21.865813,"Total Food Aid per capita (kg/cap/year)":3.465597},
      {"year": "2003", "Food availibility per capita (kg/cap/year)": 170.584228,"Production Quantity per capita (kg/cap/year)":175.141341,"Exports (all) per capita (kg/cap/year)":0.019665,"Imports (all) per capita (kg/cap/year)":16.273560,"Total Food Aid per capita (kg/cap/year)":4.429138},
      {"year": "2004", "Food availibility per capita (kg/cap/year)": 171.460093,"Production Quantity per capita (kg/cap/year)":180.675197,"Exports (all) per capita (kg/cap/year)":0.022128,"Imports (all) per capita (kg/cap/year)":18.048079,"Total Food Aid per capita (kg/cap/year)":3.340741},
      {"year": "2005", "Food availibility per capita (kg/cap/year)": 182.273141,"Production Quantity per capita (kg/cap/year)":209.584201,"Exports (all) per capita (kg/cap/year)":0.595611,"Imports (all) per capita (kg/cap/year)":15.070401,"Total Food Aid per capita (kg/cap/year)":3.728515},
      {"year": "2006", "Food availibility per capita (kg/cap/year)": 183.080942,"Production Quantity per capita (kg/cap/year)":206.543947,"Exports (all) per capita (kg/cap/year)":0.112889,"Imports (all) per capita (kg/cap/year)":17.118567,"Total Food Aid per capita (kg/cap/year)":2.662836},
      {"year": "2007", "Food availibility per capita (kg/cap/year)": 186.022569,"Production Quantity per capita (kg/cap/year)":206.492238,"Exports (all) per capita (kg/cap/year)":0.020615,"Imports (all) per capita (kg/cap/year)":11.727135,"Total Food Aid per capita (kg/cap/year)":3.340231},
      {"year": "2008", "Food availibility per capita (kg/cap/year)": 190.517047,"Production Quantity per capita (kg/cap/year)":213.618151,"Exports (all) per capita (kg/cap/year)":1.029682,"Imports (all) per capita (kg/cap/year)":12.149605,"Total Food Aid per capita (kg/cap/year)":1.894704},
      {"year": "2009", "Food availibility per capita (kg/cap/year)": 189.695677,"Production Quantity per capita (kg/cap/year)":225.263049,"Exports (all) per capita (kg/cap/year)":1.001025,"Imports (all) per capita (kg/cap/year)":12.236172,"Total Food Aid per capita (kg/cap/year)":1.356530},
      {"year": "2010", "Food availibility per capita (kg/cap/year)": 186.797089,"Production Quantity per capita (kg/cap/year)":227.230990,"Exports (all) per capita (kg/cap/year)":0.006982,"Imports (all) per capita (kg/cap/year)":12.462138,"Total Food Aid per capita (kg/cap/year)":1.971812},
      {"year": "2011", "Food availibility per capita (kg/cap/year)": 195.505390,"Production Quantity per capita (kg/cap/year)":215.380140,"Exports (all) per capita (kg/cap/year)":0.006982,"Imports (all) per capita (kg/cap/year)":16.103248,"Total Food Aid per capita (kg/cap/year)":2.658867},
      {"year": "2012", "Food availibility per capita (kg/cap/year)": 189.859699,"Production Quantity per capita (kg/cap/year)":213.564852,"Exports (all) per capita (kg/cap/year)":0.006595,"Imports (all) per capita (kg/cap/year)":20.217098,"Total Food Aid per capita (kg/cap/year)":1.967720},
      {"year": "2013", "Food availibility per capita (kg/cap/year)": 180.880179,"Production Quantity per capita (kg/cap/year)":127.917655,"Exports (all) per capita (kg/cap/year)":0.006595,"Imports (all) per capita (kg/cap/year)":20.217098,"Total Food Aid per capita (kg/cap/year)":1.967720},
    ]

Events = [{"start":"1997","end":"1997","Legend":"Total Food Aid per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Imports (all) per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Production Quantity per capita(kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Exports (all) per capita (kg/cap/year)"},{"start": "1984","end": "1985","Legend": "Kung fu riots, military intervention"},{"start": "1991","end": "1992","Legend": "Popular protest"},{"start":"1993","end":"1994","Legend":"Election of Albert Zafy as president of madagascar"},{"start":"2009","end":"2010","Legend":"Overthrow of Malagasy President Marc Ravalomanana"},{"start":"1997","end":"2001","Legend":"Economic growth"},{"start":"1999","end":"1999","Legend":"Food availibility per capita (kg/cap/year)"}]


Madagascar = alt.pd.DataFrame(Madagascar)
Events = alt.pd.DataFrame(Events)


line1 = alt.Chart(Madagascar).mark_line(color='aqua').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Food availibility per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line2 = alt.Chart(Madagascar).mark_line(color='brown').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Production Quantity per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line3 = alt.Chart(Madagascar).mark_line(color='red').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Exports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line4 = alt.Chart(Madagascar).mark_line(color='green').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Imports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line5 = alt.Chart(Madagascar).mark_line(color='grey').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y',title='Year')),
    alt.Y("Total Food Aid per capita (kg/cap/year)", axis=alt.Axis(title='kg/cap/year'))
).properties(
    width=500,
    height=300
)


rect = alt.Chart(Events).mark_rect().encode(
    x='start:T',
    x2='end:T',
    color='Legend:N'
)






rect + line1 + line2 + line3 +line4 + line5
# Out:
# alt.LayerChart(...)

# %%
Malawi = [
      {"year": "1980", "Food availibility per capita (kg/cap/year)": 183.812472,"Production Quantity per capita (kg/cap/year)":217.800389,"Exports (all) per capita (kg/cap/year)":2.552184,"Imports (all) per capita (kg/cap/year)":5.821538,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1981", "Food availibility per capita (kg/cap/year)": 183.243505,"Production Quantity per capita (kg/cap/year)":221.381897,"Exports (all) per capita (kg/cap/year)":1.406870,"Imports (all) per capita (kg/cap/year)":12.917101,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1982", "Food availibility per capita (kg/cap/year)": 184.941533,"Production Quantity per capita (kg/cap/year)":242.817137,"Exports (all) per capita (kg/cap/year)":0.525132,"Imports (all) per capita (kg/cap/year)":4.035145,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1983", "Food availibility per capita (kg/cap/year)": 183.045544,"Production Quantity per capita (kg/cap/year)":221.047684,"Exports (all) per capita (kg/cap/year)":17.983611,"Imports (all) per capita (kg/cap/year)":2.986021,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1984", "Food availibility per capita (kg/cap/year)": 174.962656,"Production Quantity per capita (kg/cap/year)":224.796007,"Exports (all) per capita (kg/cap/year)":18.782274,"Imports (all) per capita (kg/cap/year)":3.003732,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1985", "Food availibility per capita (kg/cap/year)": 177.707823,"Production Quantity per capita (kg/cap/year)":209.359487,"Exports (all) per capita (kg/cap/year)":9.001403,"Imports (all) per capita (kg/cap/year)":4.042772,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1986", "Food availibility per capita (kg/cap/year)": 169.295107,"Production Quantity per capita (kg/cap/year)":191.338224,"Exports (all) per capita (kg/cap/year)":11.309359,"Imports (all) per capita (kg/cap/year)":2.063047,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1987", "Food availibility per capita (kg/cap/year)": 168.769168,"Production Quantity per capita (kg/cap/year)":166.354587,"Exports (all) per capita (kg/cap/year)":0.142639,"Imports (all) per capita (kg/cap/year)":7.453863,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1988", "Food availibility per capita (kg/cap/year)": 170.483816,"Production Quantity per capita (kg/cap/year)":183.640502,"Exports (all) per capita (kg/cap/year)":0.513442,"Imports (all) per capita (kg/cap/year)":15.349446,"Total Food Aid per capita (kg/cap/year)":21.301378},
      {"year": "1989", "Food availibility per capita (kg/cap/year)": 170.016255,"Production Quantity per capita (kg/cap/year)":185.578500,"Exports (all) per capita (kg/cap/year)":0.449074,"Imports (all) per capita (kg/cap/year)":21.019578,"Total Food Aid per capita (kg/cap/year)":27.039943},
      {"year": "1990", "Food availibility per capita (kg/cap/year)": 153.708973,"Production Quantity per capita (kg/cap/year)":160.450071,"Exports (all) per capita (kg/cap/year)":0.232979,"Imports (all) per capita (kg/cap/year)":5.756662,"Total Food Aid per capita (kg/cap/year)":26.933186},
      {"year": "1991", "Food availibility per capita (kg/cap/year)": 158.935980,"Production Quantity per capita (kg/cap/year)":185.019300,"Exports (all) per capita (kg/cap/year)":6.592447,"Imports (all) per capita (kg/cap/year)":24.113379,"Total Food Aid per capita (kg/cap/year)":27.960665},
      {"year": "1992", "Food availibility per capita (kg/cap/year)": 159.976914,"Production Quantity per capita (kg/cap/year)":81.137525,"Exports (all) per capita (kg/cap/year)":0.312115,"Imports (all) per capita (kg/cap/year)":65.296653,"Total Food Aid per capita (kg/cap/year)":43.025638	},
      {"year": "1993", "Food availibility per capita (kg/cap/year)": 177.303774,"Production Quantity per capita (kg/cap/year)":230.548701,"Exports (all) per capita (kg/cap/year)":3.665635,"Imports (all) per capita (kg/cap/year)":14.091884,"Total Food Aid per capita (kg/cap/year)":61.881780},
      {"year": "1994", "Food availibility per capita (kg/cap/year)": 172.529164,"Production Quantity per capita (kg/cap/year)":125.368841,"Exports (all) per capita (kg/cap/year)":0.510400,"Imports (all) per capita (kg/cap/year)":36.758418,"Total Food Aid per capita (kg/cap/year)":18.795992},
      {"year": "1995", "Food availibility per capita (kg/cap/year)": 183.820764,"Production Quantity per capita (kg/cap/year)":193.561423,"Exports (all) per capita (kg/cap/year)":0.327472,"Imports (all) per capita (kg/cap/year)":22.797683,"Total Food Aid per capita (kg/cap/year)":26.250971},
      {"year": "1996", "Food availibility per capita (kg/cap/year)": 191.026093,"Production Quantity per capita (kg/cap/year)":216.832257,"Exports (all) per capita (kg/cap/year)":0.330624,"Imports (all) per capita (kg/cap/year)":13.614287,"Total Food Aid per capita (kg/cap/year)":13.500380},
      {"year": "1997", "Food availibility per capita (kg/cap/year)": 166.262032,"Production Quantity per capita (kg/cap/year)":163.766102,"Exports (all) per capita (kg/cap/year)":0.519399,"Imports (all) per capita (kg/cap/year)":13.412402,"Total Food Aid per capita (kg/cap/year)":4.825087},
      {"year": "1998", "Food availibility per capita (kg/cap/year)": 205.771865,"Production Quantity per capita (kg/cap/year)":225.739200,"Exports (all) per capita (kg/cap/year)":0.450584,"Imports (all) per capita (kg/cap/year)":17.084717,"Total Food Aid per capita (kg/cap/year)":6.712868},
      {"year": "1999", "Food availibility per capita (kg/cap/year)": 204.890542,"Production Quantity per capita (kg/cap/year)":292.743482,"Exports (all) per capita (kg/cap/year)":32.663370,"Imports (all) per capita (kg/cap/year)":12.992403,"Total Food Aid per capita (kg/cap/year)":7.394215},
      {"year": "2000", "Food availibility per capita (kg/cap/year)": 193.986198,"Production Quantity per capita (kg/cap/year)":321.316691,"Exports (all) per capita (kg/cap/year)":31.519524,"Imports (all) per capita (kg/cap/year)":3.473279,"Total Food Aid per capita (kg/cap/year)":3.454695},
      {"year": "2001", "Food availibility per capita (kg/cap/year)": 206.652753,"Production Quantity per capita (kg/cap/year)":271.704362,"Exports (all) per capita (kg/cap/year)":0.141969,"Imports (all) per capita (kg/cap/year)":13.407208,"Total Food Aid per capita (kg/cap/year)":3.893574},
      {"year": "2002", "Food availibility per capita (kg/cap/year)": 190.702879,"Production Quantity per capita (kg/cap/year)":193.916635,"Exports (all) per capita (kg/cap/year)":0.448431,"Imports (all) per capita (kg/cap/year)":53.914035,"Total Food Aid per capita (kg/cap/year)":19.105773},
      {"year": "2003", "Food availibility per capita (kg/cap/year)": 187.210628,"Production Quantity per capita (kg/cap/year)":236.186076,"Exports (all) per capita (kg/cap/year)":8.398897,"Imports (all) per capita (kg/cap/year)":9.643579,"Total Food Aid per capita (kg/cap/year)":10.923130},
      {"year": "2004", "Food availibility per capita (kg/cap/year)": 168.636388,"Production Quantity per capita (kg/cap/year)":215.524603,"Exports (all) per capita (kg/cap/year)":0.160716,"Imports (all) per capita (kg/cap/year)":23.818063,"Total Food Aid per capita (kg/cap/year)":7.197090},
      {"year": "2005", "Food availibility per capita (kg/cap/year)": 177.793653,"Production Quantity per capita (kg/cap/year)":161.314512,"Exports (all) per capita (kg/cap/year)":0.159573,"Imports (all) per capita (kg/cap/year)":28.707789,"Total Food Aid per capita (kg/cap/year)":13.185602},
      {"year": "2006", "Food availibility per capita (kg/cap/year)": 190.164546,"Production Quantity per capita (kg/cap/year)":288.301781,"Exports (all) per capita (kg/cap/year)":0.538832,"Imports (all) per capita (kg/cap/year)":16.995119,"Total Food Aid per capita (kg/cap/year)":23.948245},
      {"year": "2007", "Food availibility per capita (kg/cap/year)": 197.108919,"Production Quantity per capita (kg/cap/year)":356.696166,"Exports (all) per capita (kg/cap/year)":25.911488,"Imports (all) per capita (kg/cap/year)":13.434155,"Total Food Aid per capita (kg/cap/year)":8.015988},
      {"year": "2008", "Food availibility per capita (kg/cap/year)": 193.801947,"Production Quantity per capita (kg/cap/year)":305.864804,"Exports (all) per capita (kg/cap/year)":3.719514,"Imports (all) per capita (kg/cap/year)":13.047283,"Total Food Aid per capita (kg/cap/year)":5.926820},
      {"year": "2009", "Food availibility per capita (kg/cap/year)": 207.055720,"Production Quantity per capita (kg/cap/year)":371.698544,"Exports (all) per capita (kg/cap/year)":7.071107,"Imports (all) per capita (kg/cap/year)":10.649202,"Total Food Aid per capita (kg/cap/year)":8.130010},
      {"year": "2010", "Food availibility per capita (kg/cap/year)": 210.697833,"Production Quantity per capita (kg/cap/year)":348.269740,"Exports (all) per capita (kg/cap/year)":13.564253,"Imports (all) per capita (kg/cap/year)":6.824762,"Total Food Aid per capita (kg/cap/year)":3.984507},
      {"year": "2011", "Food availibility per capita (kg/cap/year)": 205.461043,"Production Quantity per capita (kg/cap/year)":366.965980,"Exports (all) per capita (kg/cap/year)":13.140949,"Imports (all) per capita (kg/cap/year)":11.000310,"Total Food Aid per capita (kg/cap/year)":4.535125},
      {"year": "2012", "Food availibility per capita (kg/cap/year)": 211.242811,"Production Quantity per capita (kg/cap/year)":344.973683,"Exports (all) per capita (kg/cap/year)":7.625822,"Imports (all) per capita (kg/cap/year)":6.626945,"Total Food Aid per capita (kg/cap/year)":5.168051},
      {"year": "2013", "Food availibility per capita (kg/cap/year)": 211.629649,"Production Quantity per capita (kg/cap/year)":234.551326,"Exports (all) per capita (kg/cap/year)":7.625822,"Imports (all) per capita (kg/cap/year)":6.626945,"Total Food Aid per capita (kg/cap/year)":5.168051},
    ]

Events = [{"start":"1999","end":"1999","Legend":"Food availibility per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Total Food Aid per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Imports (all) per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Production Quantity per capita(kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Exports (all) per capita (kg/cap/year)"},{"start": "1994","end": "1995","Legend": "End of a 30-year one-party regime"},{"start": "1980","end": "1990","Legend": "Authoritarian regime"},{"start": "1995","end": "2013","Legend": "Democratic regime"}]


Malawi = alt.pd.DataFrame(Malawi)
Events = alt.pd.DataFrame(Events)


line1 = alt.Chart(Malawi).mark_line(color='green').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Food availibility per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line2 = alt.Chart(Malawi).mark_line(color='purple').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Production Quantity per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line3 = alt.Chart(Malawi).mark_line(color='aqua').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Exports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line4 = alt.Chart(Malawi).mark_line(color='yellow').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Imports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line5 = alt.Chart(Malawi).mark_line(color='pink').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y',title='Year')),
    alt.Y("Total Food Aid per capita (kg/cap/year)", axis=alt.Axis(title='kg/cap/year'))
).properties(
    width=500,
    height=300
)


rect = alt.Chart(Events).mark_rect().encode(
    x='start:T',
    x2='end:T',
    color='Legend:N'
)






rect + line1 + line2 + line3 +line4 + line5
# Out:
# alt.LayerChart(...)

# %%
 Mozambique= [
      {"year": "1980", "Food availibility per capita (kg/cap/year)": 171.439408,"Production Quantity per capita (kg/cap/year)":162.711510,"Exports (all) per capita (kg/cap/year)":0.823316,"Imports (all) per capita (kg/cap/year)":30.409929,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1981", "Food availibility per capita (kg/cap/year)": 164.060362,"Production Quantity per capita (kg/cap/year)":159.014335,"Exports (all) per capita (kg/cap/year)":0.200932,"Imports (all) per capita (kg/cap/year)":25.784842,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1982", "Food availibility per capita (kg/cap/year)": 157.462977,"Production Quantity per capita (kg/cap/year)":153.389195,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":24.199749,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1983", "Food availibility per capita (kg/cap/year)": 152.511657,"Production Quantity per capita (kg/cap/year)":150.668776,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":21.300151,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1984", "Food availibility per capita (kg/cap/year)": 164.706496,"Production Quantity per capita (kg/cap/year)":152.299238,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":32.626184,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1985", "Food availibility per capita (kg/cap/year)": 177.432024,"Production Quantity per capita (kg/cap/year)":153.843248,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":44.935883,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1986", "Food availibility per capita (kg/cap/year)": 157.148552,"Production Quantity per capita (kg/cap/year)":158.884010,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":18.618653,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1987", "Food availibility per capita (kg/cap/year)": 154.529193,"Production Quantity per capita (kg/cap/year)":142.708475,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":32.621748,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1988", "Food availibility per capita (kg/cap/year)": 165.276328,"Production Quantity per capita (kg/cap/year)":141.264897,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":47.170310,"Total Food Aid per capita (kg/cap/year)":57.881876},
      {"year": "1989", "Food availibility per capita (kg/cap/year)": 156.609771,"Production Quantity per capita (kg/cap/year)":145.372195,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":35.410280,"Total Food Aid per capita (kg/cap/year)":44.973860},
      {"year": "1990", "Food availibility per capita (kg/cap/year)": 178.121293,"Production Quantity per capita (kg/cap/year)":176.672834,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":39.886443,"Total Food Aid per capita (kg/cap/year)":36.269734},
      {"year": "1991", "Food availibility per capita (kg/cap/year)": 157.135357,"Production Quantity per capita (kg/cap/year)":138.283043,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":50.680766,"Total Food Aid per capita (kg/cap/year)":43.972427},
      {"year": "1992", "Food availibility per capita (kg/cap/year)": 160.744914,"Production Quantity per capita (kg/cap/year)":102.278889,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":76.446330,"Total Food Aid per capita (kg/cap/year)":80.951422},
      {"year": "1993", "Food availibility per capita (kg/cap/year)": 156.623954,"Production Quantity per capita (kg/cap/year)":139.303475,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":35.568306,"Total Food Aid per capita (kg/cap/year)":35.122791},
      {"year": "1994", "Food availibility per capita (kg/cap/year)": 154.170560,"Production Quantity per capita (kg/cap/year)":131.361125,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":35.098685,"Total Food Aid per capita (kg/cap/year)":28.793810},
      {"year": "1995", "Food availibility per capita (kg/cap/year)": 164.570306,"Production Quantity per capita (kg/cap/year)":166.528223,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":27.541178,"Total Food Aid per capita (kg/cap/year)":27.332790},
      {"year": "1996", "Food availibility per capita (kg/cap/year)": 173.043269,"Production Quantity per capita (kg/cap/year)":188.555622,"Exports (all) per capita (kg/cap/year)":1.827819,"Imports (all) per capita (kg/cap/year)":23.769386,"Total Food Aid per capita (kg/cap/year)":10.674264},
      {"year": "1997", "Food availibility per capita (kg/cap/year)": 183.487892,"Production Quantity per capita (kg/cap/year)":204.760819,"Exports (all) per capita (kg/cap/year)":1.482624,"Imports (all) per capita (kg/cap/year)":18.953735,"Total Food Aid per capita (kg/cap/year)":12.190403},
      {"year": "1998", "Food availibility per capita (kg/cap/year)": 187.106344,"Production Quantity per capita (kg/cap/year)":213.921073,"Exports (all) per capita (kg/cap/year)":6.938020,"Imports (all) per capita (kg/cap/year)":30.995581,"Total Food Aid per capita (kg/cap/year)":12.409292},
      {"year": "1999", "Food availibility per capita (kg/cap/year)": 200.180193,"Production Quantity per capita (kg/cap/year)":226.808116,"Exports (all) per capita (kg/cap/year)":6.765900,"Imports (all) per capita (kg/cap/year)":35.113928,"Total Food Aid per capita (kg/cap/year)":10.706361},
      {"year": "2000", "Food availibility per capita (kg/cap/year)": 190.497715,"Production Quantity per capita (kg/cap/year)":199.051914,"Exports (all) per capita (kg/cap/year)":1.922971,"Imports (all) per capita (kg/cap/year)":30.311497,"Total Food Aid per capita (kg/cap/year)":11.309698},
      {"year": "2001", "Food availibility per capita (kg/cap/year)": 190.975762,"Production Quantity per capita (kg/cap/year)":211.485096,"Exports (all) per capita (kg/cap/year)":4.547643,"Imports (all) per capita (kg/cap/year)":31.738250,"Total Food Aid per capita (kg/cap/year)":14.977581},
      {"year": "2002", "Food availibility per capita (kg/cap/year)": 186.436047,"Production Quantity per capita (kg/cap/year)":207.861952,"Exports (all) per capita (kg/cap/year)":10.677158,"Imports (all) per capita (kg/cap/year)":37.415429,"Total Food Aid per capita (kg/cap/year)":11.938416},
      {"year": "2003", "Food availibility per capita (kg/cap/year)": 198.173586,"Production Quantity per capita (kg/cap/year)":217.674216,"Exports (all) per capita (kg/cap/year)":4.817272,"Imports (all) per capita (kg/cap/year)":41.920516,"Total Food Aid per capita (kg/cap/year)":13.187188},
      {"year": "2004", "Food availibility per capita (kg/cap/year)": 202.107226,"Production Quantity per capita (kg/cap/year)":226.828724,"Exports (all) per capita (kg/cap/year)":8.643753,"Imports (all) per capita (kg/cap/year)":39.185368,"Total Food Aid per capita (kg/cap/year)":8.737024},
      {"year": "2005", "Food availibility per capita (kg/cap/year)": 207.783261,"Production Quantity per capita (kg/cap/year)":181.500717,"Exports (all) per capita (kg/cap/year)":9.147878,"Imports (all) per capita (kg/cap/year)":47.451091,"Total Food Aid per capita (kg/cap/year)":6.666249},
      {"year": "2006", "Food availibility per capita (kg/cap/year)": 207.217178,"Production Quantity per capita (kg/cap/year)":223.481931,"Exports (all) per capita (kg/cap/year)":3.992364,"Imports (all) per capita (kg/cap/year)":44.513197,"Total Food Aid per capita (kg/cap/year)":8.010721},
      {"year": "2007", "Food availibility per capita (kg/cap/year)": 193.297920,"Production Quantity per capita (kg/cap/year)":192.486174,"Exports (all) per capita (kg/cap/year)":6.877328,"Imports (all) per capita (kg/cap/year)":33.670307,"Total Food Aid per capita (kg/cap/year)":4.284213},
      {"year": "2008", "Food availibility per capita (kg/cap/year)": 199.373520,"Production Quantity per capita (kg/cap/year)":176.811433,"Exports (all) per capita (kg/cap/year)":6.716582,"Imports (all) per capita (kg/cap/year)":44.838356,"Total Food Aid per capita (kg/cap/year)":6.663867},
      {"year": "2009", "Food availibility per capita (kg/cap/year)": 199.424811,"Production Quantity per capita (kg/cap/year)":215.469831,"Exports (all) per capita (kg/cap/year)":4.374707,"Imports (all) per capita (kg/cap/year)":37.148345,"Total Food Aid per capita (kg/cap/year)":9.060010},
      {"year": "2010", "Food availibility per capita (kg/cap/year)": 259.001093,"Production Quantity per capita (kg/cap/year)":280.061328,"Exports (all) per capita (kg/cap/year)":7.695328,"Imports (all) per capita (kg/cap/year)":40.471720,"Total Food Aid per capita (kg/cap/year)":5.328313},
      {"year": "2011", "Food availibility per capita (kg/cap/year)": 260.337511,"Production Quantity per capita (kg/cap/year)":283.488770,"Exports (all) per capita (kg/cap/year)":7.521998,"Imports (all) per capita (kg/cap/year)":34.741914,"Total Food Aid per capita (kg/cap/year)":5.971422},
      {"year": "2012", "Food availibility per capita (kg/cap/year)": 261.399426,"Production Quantity per capita (kg/cap/year)":245.857430,"Exports (all) per capita (kg/cap/year)":1.225799,"Imports (all) per capita (kg/cap/year)":34.176671,"Total Food Aid per capita (kg/cap/year)":5.987530},
      {"year": "2013", "Food availibility per capita (kg/cap/year)": 261.741299,"Production Quantity per capita (kg/cap/year)":83.950699,"Exports (all) per capita (kg/cap/year)":1.225799,"Imports (all) per capita (kg/cap/year)":34.176671,"Total Food Aid per capita (kg/cap/year)":5.987530},
    ]

Events = [{"start":"1999","end":"1999","Legend":"Food availibility per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Total Food Aid per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Imports (all) per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Production Quantity per capita(kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Exports (all) per capita (kg/cap/year)"},{"start": "1980","end": "1992","Legend": "Civil war"},{"start":"1994","end":"1995","Legend":"First democratic election - election of Joachim Chissano"},{"start":"2005","end":"2013","Legend":"Armando Guebuza is president"}]


Mozambique = alt.pd.DataFrame(Mozambique)
Events = alt.pd.DataFrame(Events)


line1 = alt.Chart(Mozambique).mark_line(color='green').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Food availibility per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line2 = alt.Chart(Mozambique).mark_line(color='purple').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Production Quantity per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line3 = alt.Chart(Mozambique).mark_line(color='red').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Exports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line4 = alt.Chart(Mozambique).mark_line(color='yellow').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Imports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line5 = alt.Chart(Mozambique).mark_line(color='pink').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y',title='Year')),
    alt.Y("Total Food Aid per capita (kg/cap/year)", axis=alt.Axis(title='kg/cap/year'))
).properties(
    width=500,
    height=300
)


rect = alt.Chart(Events).mark_rect().encode(
    x='start:T',
    x2='end:T',
    color='Legend:N'
)






rect + line1 + line2 + line3 +line4 + line5
# Out:
# alt.LayerChart(...)

# %%
Namibia= [
      {"year": "1980", "Food availibility per capita (kg/cap/year)": 156.782306,"Production Quantity per capita (kg/cap/year)":127.823884,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":53.307009,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1981", "Food availibility per capita (kg/cap/year)": 161.413031,"Production Quantity per capita (kg/cap/year)":127.750589,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":57.971014,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1982", "Food availibility per capita (kg/cap/year)": 161.059501,"Production Quantity per capita (kg/cap/year)":128.314679,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":60.548723,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1983", "Food availibility per capita (kg/cap/year)": 160.987105,"Production Quantity per capita (kg/cap/year)":131.417569,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":60.073937,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1984", "Food availibility per capita (kg/cap/year)": 159.595100,"Production Quantity per capita (kg/cap/year)":132.425142,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":61.096137,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1985", "Food availibility per capita (kg/cap/year)": 151.555568,"Production Quantity per capita (kg/cap/year)":106.915112,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":79.107826,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1986", "Food availibility per capita (kg/cap/year)": 149.705745,"Production Quantity per capita (kg/cap/year)":118.422140,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":63.264435,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1987", "Food availibility per capita (kg/cap/year)": 160.687877,"Production Quantity per capita (kg/cap/year)":105.235046,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":81.920673,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1988", "Food availibility per capita (kg/cap/year)": 158.084905,"Production Quantity per capita (kg/cap/year)":112.560503,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":71.161043,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1989", "Food availibility per capita (kg/cap/year)": 150.346457,"Production Quantity per capita (kg/cap/year)":117.363269,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":66.700955,"Total Food Aid per capita (kg/cap/year)":1.698939},
      {"year": "1990", "Food availibility per capita (kg/cap/year)": 143.097261,"Production Quantity per capita (kg/cap/year)":114.825640,"Exports (all) per capita (kg/cap/year)":4.381625,"Imports (all) per capita (kg/cap/year)":40.070671,"Total Food Aid per capita (kg/cap/year)":7.834441},
      {"year": "1991", "Food availibility per capita (kg/cap/year)": 137.072965,"Production Quantity per capita (kg/cap/year)":118.866803,"Exports (all) per capita (kg/cap/year)":12.764505,"Imports (all) per capita (kg/cap/year)":50.443686,"Total Food Aid per capita (kg/cap/year)":6.628044},
      {"year": "1992", "Food availibility per capita (kg/cap/year)": 152.211281,"Production Quantity per capita (kg/cap/year)":59.563507,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":119.629874,"Total Food Aid per capita (kg/cap/year)":15.155859},
      {"year": "1993", "Food availibility per capita (kg/cap/year)": 150.122595,"Production Quantity per capita (kg/cap/year)":87.364412,"Exports (all) per capita (kg/cap/year)":1.026958,"Imports (all) per capita (kg/cap/year)":78.305520,"Total Food Aid per capita (kg/cap/year)":19.145370},
      {"year": "1994", "Food availibility per capita (kg/cap/year)": 151.949395,"Production Quantity per capita (kg/cap/year)":112.006569,"Exports (all) per capita (kg/cap/year)":0.623441,"Imports (all) per capita (kg/cap/year)":54.862843,"Total Food Aid per capita (kg/cap/year)":0.651204},
      {"year": "1995", "Food availibility per capita (kg/cap/year)": 148.695903,"Production Quantity per capita (kg/cap/year)":78.132145,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":83.585706,"Total Food Aid per capita (kg/cap/year)":2.553599},
      {"year": "1996", "Food availibility per capita (kg/cap/year)": 155.145082,"Production Quantity per capita (kg/cap/year)":94.137114,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":72.898295,"Total Food Aid per capita (kg/cap/year)":6.802322},
      {"year": "1997", "Food availibility per capita (kg/cap/year)": 172.788745,"Production Quantity per capita (kg/cap/year)":146.805687,"Exports (all) per capita (kg/cap/year)":6.004449,"Imports (all) per capita (kg/cap/year)":82.026048,"Total Food Aid per capita (kg/cap/year)":0.617337},
      {"year": "1998", "Food availibility per capita (kg/cap/year)": 160.723411,"Production Quantity per capita (kg/cap/year)":79.077836,"Exports (all) per capita (kg/cap/year)":34.317871,"Imports (all) per capita (kg/cap/year)":104.085712,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1999", "Food availibility per capita (kg/cap/year)": 165.534903,"Production Quantity per capita (kg/cap/year)":79.982340,"Exports (all) per capita (kg/cap/year)":6.086944,"Imports (all) per capita (kg/cap/year)":101.447733,"Total Food Aid per capita (kg/cap/year)":1.206798},
      {"year": "2000", "Food availibility per capita (kg/cap/year)": 169.590951,"Production Quantity per capita (kg/cap/year)":103.607288,"Exports (all) per capita (kg/cap/year)":5.518968,"Imports (all) per capita (kg/cap/year)":84.841055,"Total Food Aid per capita (kg/cap/year)":1.121735},
      {"year": "2001", "Food availibility per capita (kg/cap/year)": 166.891655,"Production Quantity per capita (kg/cap/year)":97.669492,"Exports (all) per capita (kg/cap/year)":6.833778,"Imports (all) per capita (kg/cap/year)":88.398775,"Total Food Aid per capita (kg/cap/year)":2.623121},
      {"year": "2002", "Food availibility per capita (kg/cap/year)": 170.538376,"Production Quantity per capita (kg/cap/year)":95.230502,"Exports (all) per capita (kg/cap/year)":9.095316,"Imports (all) per capita (kg/cap/year)":115.019904,"Total Food Aid per capita (kg/cap/year)":13.418030},
      {"year": "2003", "Food availibility per capita (kg/cap/year)": 173.562274,"Production Quantity per capita (kg/cap/year)":94.078677,"Exports (all) per capita (kg/cap/year)":0.111594,"Imports (all) per capita (kg/cap/year)":123.054811,"Total Food Aid per capita (kg/cap/year)":12.704499},
      {"year": "2004", "Food availibility per capita (kg/cap/year)": 178.956393,"Production Quantity per capita (kg/cap/year)":112.945880,"Exports (all) per capita (kg/cap/year)":0.059226,"Imports (all) per capita (kg/cap/year)":90.118695,"Total Food Aid per capita (kg/cap/year)":3.327747},
      {"year": "2005", "Food availibility per capita (kg/cap/year)": 180.047599,"Production Quantity per capita (kg/cap/year)":120.626698,"Exports (all) per capita (kg/cap/year)":17.846400,"Imports (all) per capita (kg/cap/year)":99.746851,"Total Food Aid per capita (kg/cap/year)":0.848190},
      {"year": "2006", "Food availibility per capita (kg/cap/year)": 182.884123,"Production Quantity per capita (kg/cap/year)":129.837526,"Exports (all) per capita (kg/cap/year)":0.061347,"Imports (all) per capita (kg/cap/year)":77.618919,"Total Food Aid per capita (kg/cap/year)":3.650394},
      {"year": "2007", "Food availibility per capita (kg/cap/year)": 181.979736,"Production Quantity per capita (kg/cap/year)":100.509173,"Exports (all) per capita (kg/cap/year)":5.169511,"Imports (all) per capita (kg/cap/year)":83.239027,"Total Food Aid per capita (kg/cap/year)":5.042682},
      {"year": "2008", "Food availibility per capita (kg/cap/year)": 174.878179,"Production Quantity per capita (kg/cap/year)":92.448479,"Exports (all) per capita (kg/cap/year)":8.235775,"Imports (all) per capita (kg/cap/year)":97.379690,"Total Food Aid per capita (kg/cap/year)":2.281106},
      {"year": "2009", "Food availibility per capita (kg/cap/year)": 164.356118,"Production Quantity per capita (kg/cap/year)":92.659822,"Exports (all) per capita (kg/cap/year)":3.621290,"Imports (all) per capita (kg/cap/year)":95.515657,"Total Food Aid per capita (kg/cap/year)":0.177335},
      {"year": "2010", "Food availibility per capita (kg/cap/year)": 172.026357,"Production Quantity per capita (kg/cap/year)":112.210904,"Exports (all) per capita (kg/cap/year)":8.812498,"Imports (all) per capita (kg/cap/year)":78.206790,"Total Food Aid per capita (kg/cap/year)":0.659979},
      {"year": "2011", "Food availibility per capita (kg/cap/year)": 174.343928,"Production Quantity per capita (kg/cap/year)":95.747250,"Exports (all) per capita (kg/cap/year)":0.911761,"Imports (all) per capita (kg/cap/year)":69.339975,"Total Food Aid per capita (kg/cap/year)":0.567049},
      {"year": "2012", "Food availibility per capita (kg/cap/year)": 175.182253,"Production Quantity per capita (kg/cap/year)":114.835942,"Exports (all) per capita (kg/cap/year)":2.165369,"Imports (all) per capita (kg/cap/year)":82.972124,"Total Food Aid per capita (kg/cap/year)":0.403411},
      {"year": "2013", "Food availibility per capita (kg/cap/year)": 175.848092,"Production Quantity per capita (kg/cap/year)":39.850250,"Exports (all) per capita (kg/cap/year)":2.165369,"Imports (all) per capita (kg/cap/year)":82.972124,"Total Food Aid per capita (kg/cap/year)":0.403411},
    ]

Events = [{"start":"1999","end":"1999","Legend":"Food availibility per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Total Food Aid per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Imports (all) per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Production Quantity per capita(kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Exports (all) per capita (kg/cap/year)"},{"start": "1991","end": "1992","Legend": "Declaration of Independence"},{"start": "2005","end": "2013","Legend": "Hifikepunye Pohamba is president"},{"start": "1980","end": "1981","Legend": "First government of South West Africa/Namibia"},{"start": "1983","end": "1984","Legend": "The National Assembly is dissolved"},{"start": "1985","end": "1986","Legend": "Intermediate government set up by south africa"}]


Namibia = alt.pd.DataFrame(Namibia)
Events = alt.pd.DataFrame(Events)


line1 = alt.Chart(Namibia).mark_line(color='aqua').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Food availibility per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line2 = alt.Chart(Namibia).mark_line(color='pink').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Production Quantity per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line3 = alt.Chart(Namibia).mark_line(color='orange').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Exports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line4 = alt.Chart(Namibia).mark_line(color='yellow').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Imports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line5 = alt.Chart(Namibia).mark_line(color='grey').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y',title='Year')),
    alt.Y("Total Food Aid per capita (kg/cap/year)", axis=alt.Axis(title='kg/cap/year'))
).properties(
    width=500,
    height=300
)


rect = alt.Chart(Events).mark_rect().encode(
    x='start:T',
    x2='end:T',
    color='Legend:N'
)






rect + line1 + line2 + line3 +line4 + line5
# Out:
# alt.LayerChart(...)

# %%
Swaziland = [
      {"year": "1980", "Food availibility per capita (kg/cap/year)": 155.588699,"Production Quantity per capita (kg/cap/year)":189.664154,"Exports (all) per capita (kg/cap/year)":0.170813,"Imports (all) per capita (kg/cap/year)":33.830846,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1981", "Food availibility per capita (kg/cap/year)": 159.346641,"Production Quantity per capita (kg/cap/year)":174.260172,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":88.827697,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1982", "Food availibility per capita (kg/cap/year)": 162.718057,"Production Quantity per capita (kg/cap/year)":102.574485,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":68.308294,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1983", "Food availibility per capita (kg/cap/year)": 162.376886,"Production Quantity per capita (kg/cap/year)":64.831318,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":67.658574,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1984", "Food availibility per capita (kg/cap/year)": 165.589851,"Production Quantity per capita (kg/cap/year)":242.456333,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":118.647059,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1985", "Food availibility per capita (kg/cap/year)": 151.601143,"Production Quantity per capita (kg/cap/year)":268.442610,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":44.580737,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1986", "Food availibility per capita (kg/cap/year)": 159.518665,"Production Quantity per capita (kg/cap/year)":162.771538,"Exports (all) per capita (kg/cap/year)":6.394558,"Imports (all) per capita (kg/cap/year)":60.137415,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1987", "Food availibility per capita (kg/cap/year)": 163.592688,"Production Quantity per capita (kg/cap/year)":151.395021,"Exports (all) per capita (kg/cap/year)":12.890625,"Imports (all) per capita (kg/cap/year)":74.501302,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1988", "Food availibility per capita (kg/cap/year)": 155.983019,"Production Quantity per capita (kg/cap/year)":189.973892,"Exports (all) per capita (kg/cap/year)":2.493766,"Imports (all) per capita (kg/cap/year)":101.066810,"Total Food Aid per capita (kg/cap/year)":25.765382},
      {"year": "1989", "Food availibility per capita (kg/cap/year)": 153.072325,"Production Quantity per capita (kg/cap/year)":134.315856,"Exports (all) per capita (kg/cap/year)":0.239808,"Imports (all) per capita (kg/cap/year)":110.623310,"Total Food Aid per capita (kg/cap/year)":5.712377},
      {"year": "1990", "Food availibility per capita (kg/cap/year)": 189.866422,"Production Quantity per capita (kg/cap/year)":171.896704,"Exports (all) per capita (kg/cap/year)":11.587486,"Imports (all) per capita (kg/cap/year)":47.999290,"Total Food Aid per capita (kg/cap/year)":14.360960},
      {"year": "1991", "Food availibility per capita (kg/cap/year)": 212.021716,"Production Quantity per capita (kg/cap/year)":172.736496,"Exports (all) per capita (kg/cap/year)":11.382300,"Imports (all) per capita (kg/cap/year)":106.645435,"Total Food Aid per capita (kg/cap/year)":6.304096},
      {"year": "1992", "Food availibility per capita (kg/cap/year)": 183.628668,"Production Quantity per capita (kg/cap/year)":75.819965,"Exports (all) per capita (kg/cap/year)":11.013216,"Imports (all) per capita (kg/cap/year)":111.439199,"Total Food Aid per capita (kg/cap/year)":20.331118},
      {"year": "1993", "Food availibility per capita (kg/cap/year)": 173.309277,"Production Quantity per capita (kg/cap/year)":92.995696,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":82.368838,"Total Food Aid per capita (kg/cap/year)":37.462902},
      {"year": "1994", "Food availibility per capita (kg/cap/year)": 191.785178,"Production Quantity per capita (kg/cap/year)":121.354901,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":93.509746,"Total Food Aid per capita (kg/cap/year)":13.104437},
      {"year": "1995", "Food availibility per capita (kg/cap/year)": 140.881454,"Production Quantity per capita (kg/cap/year)":93.716705,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":58.360218,"Total Food Aid per capita (kg/cap/year)":7.556835},
      {"year": "1996", "Food availibility per capita (kg/cap/year)": 193.956758,"Production Quantity per capita (kg/cap/year)":168.211747,"Exports (all) per capita (kg/cap/year)":2.030457,"Imports (all) per capita (kg/cap/year)":65.002099,"Total Food Aid per capita (kg/cap/year)":10.050161},
      {"year": "1997", "Food availibility per capita (kg/cap/year)": 164.285137,"Production Quantity per capita (kg/cap/year)":150.661673,"Exports (all) per capita (kg/cap/year)":2.879038,"Imports (all) per capita (kg/cap/year)":73.964536,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1998", "Food availibility per capita (kg/cap/year)": 166.432709,"Production Quantity per capita (kg/cap/year)":129.011225,"Exports (all) per capita (kg/cap/year)":5.948572,"Imports (all) per capita (kg/cap/year)":87.155166,"Total Food Aid per capita (kg/cap/year)":5.314626},
      {"year": "1999", "Food availibility per capita (kg/cap/year)": 165.189251,"Production Quantity per capita (kg/cap/year)":132.044084,"Exports (all) per capita (kg/cap/year)":3.935411,"Imports (all) per capita (kg/cap/year)":80.337811,"Total Food Aid per capita (kg/cap/year)":5.218273},
      {"year": "2000", "Food availibility per capita (kg/cap/year)": 164.636978,"Production Quantity per capita (kg/cap/year)":119.577671,"Exports (all) per capita (kg/cap/year)":2.340723,"Imports (all) per capita (kg/cap/year)":94.711285,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "2001", "Food availibility per capita (kg/cap/year)": 162.267616,"Production Quantity per capita (kg/cap/year)":90.065414,"Exports (all) per capita (kg/cap/year)":1.939571,"Imports (all) per capita (kg/cap/year)":87.091485,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "2002", "Food availibility per capita (kg/cap/year)": 165.145558,"Production Quantity per capita (kg/cap/year)":76.516312,"Exports (all) per capita (kg/cap/year)":2.589432,"Imports (all) per capita (kg/cap/year)":109.495706,"Total Food Aid per capita (kg/cap/year)":16.335263},
      {"year": "2003", "Food availibility per capita (kg/cap/year)": 160.951190,"Production Quantity per capita (kg/cap/year)":76.509500,"Exports (all) per capita (kg/cap/year)":3.201758,"Imports (all) per capita (kg/cap/year)":122.935245,"Total Food Aid per capita (kg/cap/year)":25.223664},
      {"year": "2004", "Food availibility per capita (kg/cap/year)": 163.383426,"Production Quantity per capita (kg/cap/year)":76.706493,"Exports (all) per capita (kg/cap/year)":2.145597,"Imports (all) per capita (kg/cap/year)":128.405969,"Total Food Aid per capita (kg/cap/year)":12.823454},
      {"year": "2005", "Food availibility per capita (kg/cap/year)": 161.345016,"Production Quantity per capita (kg/cap/year)":81.666755,"Exports (all) per capita (kg/cap/year)":3.822571,"Imports (all) per capita (kg/cap/year)":117.902568,"Total Food Aid per capita (kg/cap/year)":12.141071},
      {"year": "2006", "Food availibility per capita (kg/cap/year)": 160.619696,"Production Quantity per capita (kg/cap/year)":73.680571,"Exports (all) per capita (kg/cap/year)":1.884402,"Imports (all) per capita (kg/cap/year)":118.579853,"Total Food Aid per capita (kg/cap/year)":16.451669},
      {"year": "2007", "Food availibility per capita (kg/cap/year)": 157.420266,"Production Quantity per capita (kg/cap/year)":54.612741,"Exports (all) per capita (kg/cap/year)":1.426792,"Imports (all) per capita (kg/cap/year)":132.046734,"Total Food Aid per capita (kg/cap/year)":15.637120},
      {"year": "2008", "Food availibility per capita (kg/cap/year)": 160.272014,"Production Quantity per capita (kg/cap/year)":67.472405,"Exports (all) per capita (kg/cap/year)":1.401979,"Imports (all) per capita (kg/cap/year)":114.596234,"Total Food Aid per capita (kg/cap/year)":18.024989},
      {"year": "2009", "Food availibility per capita (kg/cap/year)": 158.137415,"Production Quantity per capita (kg/cap/year)":75.494505,"Exports (all) per capita (kg/cap/year)":1.380044,"Imports (all) per capita (kg/cap/year)":122.247129,"Total Food Aid per capita (kg/cap/year)":2.913151},
      {"year": "2010", "Food availibility per capita (kg/cap/year)": 160.432484,"Production Quantity per capita (kg/cap/year)":78.322441,"Exports (all) per capita (kg/cap/year)":1.359099,"Imports (all) per capita (kg/cap/year)":97.457544,"Total Food Aid per capita (kg/cap/year)":5.411157},
      {"year": "2011", "Food availibility per capita (kg/cap/year)": 161.866048,"Production Quantity per capita (kg/cap/year)":85.584528,"Exports (all) per capita (kg/cap/year)":1.339893,"Imports (all) per capita (kg/cap/year)":112.871693,"Total Food Aid per capita (kg/cap/year)":14.151307},
      {"year": "2012", "Food availibility per capita (kg/cap/year)": 161.344064,"Production Quantity per capita (kg/cap/year)":77.518926,"Exports (all) per capita (kg/cap/year)":1.321222,"Imports (all) per capita (kg/cap/year)":120.725120,"Total Food Aid per capita (kg/cap/year)":6.945180},
      {"year": "2013", "Food availibility per capita (kg/cap/year)": 162.491229,"Production Quantity per capita (kg/cap/year)":66.774454,"Exports (all) per capita (kg/cap/year)":1.321222,"Imports (all) per capita (kg/cap/year)":120.725120,"Total Food Aid per capita (kg/cap/year)":6.945180},
    ]

Events = [{"start":"1999","end":"1999","Legend":"Food availibility per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Total Food Aid per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Imports (all) per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Production Quantity per capita(kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Exports (all) per capita (kg/cap/year)"},{"start": "1982","end": "1983","Legend": "Death of King Sobhuza II"},{"start":"1986","end":"2013","Legend":"Mswati III absolute monarch"},{"start":"2005","end":"2006","Legend":"First constitution by the swazis"},{"start":"2006","end":"2007","Legend":"Entry into force of the constitution"}]


Swaziland = alt.pd.DataFrame(Swaziland)
Events = alt.pd.DataFrame(Events)


line1 = alt.Chart(Swaziland).mark_line(color='green').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Food availibility per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line2 = alt.Chart(Swaziland).mark_line(color='pink').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Production Quantity per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line3 = alt.Chart(Swaziland).mark_line(color='red').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Exports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line4 = alt.Chart(Swaziland).mark_line(color='yellow').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Imports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line5 = alt.Chart(Swaziland).mark_line(color='brown').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y',title='Year')),
    alt.Y("Total Food Aid per capita (kg/cap/year)", axis=alt.Axis(title='kg/cap/year'))
).properties(
    width=500,
    height=300
)


rect = alt.Chart(Events).mark_rect().encode(
    x='start:T',
    x2='end:T',
    color='Legend:N'
)






rect + line1 + line2 + line3 +line4 + line5
# Out:
# alt.LayerChart(...)

# %%
Zambia = [
      {"year": "1980", "Food availibility per capita (kg/cap/year)": 213.006102,"Production Quantity per capita (kg/cap/year)":192.295526,"Exports (all) per capita (kg/cap/year)":0.000346,"Imports (all) per capita (kg/cap/year)":86.362494,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1981", "Food availibility per capita (kg/cap/year)": 209.943961,"Production Quantity per capita (kg/cap/year)":198.094553,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":41.971196,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1982", "Food availibility per capita (kg/cap/year)": 198.113501,"Production Quantity per capita (kg/cap/year)":151.010029,"Exports (all) per capita (kg/cap/year)":0.000487,"Imports (all) per capita (kg/cap/year)":33.364050,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1983", "Food availibility per capita (kg/cap/year)": 200.652256,"Production Quantity per capita (kg/cap/year)":175.259493,"Exports (all) per capita (kg/cap/year)":0.0,"Imports (all) per capita (kg/cap/year)":32.943005,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1984", "Food availibility per capita (kg/cap/year)": 199.174007,"Production Quantity per capita (kg/cap/year)":161.518359,"Exports (all) per capita (kg/cap/year)":0.000456,"Imports (all) per capita (kg/cap/year)":36.490996,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1985", "Food availibility per capita (kg/cap/year)": 192.383677,"Production Quantity per capita (kg/cap/year)":196.603135,"Exports (all) per capita (kg/cap/year)":0.090494,"Imports (all) per capita (kg/cap/year)":30.873677,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1986", "Food availibility per capita (kg/cap/year)": 194.505178,"Production Quantity per capita (kg/cap/year)":210.354002,"Exports (all) per capita (kg/cap/year)":5.017576,"Imports (all) per capita (kg/cap/year)":23.534210,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1987", "Food availibility per capita (kg/cap/year)": 192.854528,"Production Quantity per capita (kg/cap/year)":183.094943,"Exports (all) per capita (kg/cap/year)":0.033213,"Imports (all) per capita (kg/cap/year)":18.766930,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1988", "Food availibility per capita (kg/cap/year)": 195.415408,"Production Quantity per capita (kg/cap/year)":299.529440,"Exports (all) per capita (kg/cap/year)":0.070640,"Imports (all) per capita (kg/cap/year)":22.684849	,"Total Food Aid per capita (kg/cap/year)":26.358619},
      {"year": "1989", "Food availibility per capita (kg/cap/year)": 193.750858,"Production Quantity per capita (kg/cap/year)":287.189740,"Exports (all) per capita (kg/cap/year)":0.065385,"Imports (all) per capita (kg/cap/year)":16.084739,"Total Food Aid per capita (kg/cap/year)":8.061070},
      {"year": "1990", "Food availibility per capita (kg/cap/year)": 198.835274,"Production Quantity per capita (kg/cap/year)":184.998547,"Exports (all) per capita (kg/cap/year)":19.084776,"Imports (all) per capita (kg/cap/year)":4.553984,"Total Food Aid per capita (kg/cap/year)":3.460993},
      {"year": "1991", "Food availibility per capita (kg/cap/year)": 178.578242,"Production Quantity per capita (kg/cap/year)":183.580111,"Exports (all) per capita (kg/cap/year)":22.052029,"Imports (all) per capita (kg/cap/year)":36.803347,"Total Food Aid per capita (kg/cap/year)":8.575685},
      {"year": "1992", "Food availibility per capita (kg/cap/year)": 169.362031,"Production Quantity per capita (kg/cap/year)":104.022917,"Exports (all) per capita (kg/cap/year)":6.048924,"Imports (all) per capita (kg/cap/year)":99.010877,"Total Food Aid per capita (kg/cap/year)":62.814608},
      {"year": "1993", "Food availibility per capita (kg/cap/year)": 183.264442,"Production Quantity per capita (kg/cap/year)":240.342525,"Exports (all) per capita (kg/cap/year)":13.603177,"Imports (all) per capita (kg/cap/year)":4.313462,"Total Food Aid per capita (kg/cap/year)":47.363496},
      {"year": "1994", "Food availibility per capita (kg/cap/year)": 175.286235,"Production Quantity per capita (kg/cap/year)":165.043958,"Exports (all) per capita (kg/cap/year)":0.017750,"Imports (all) per capita (kg/cap/year)":45.293730,"Total Food Aid per capita (kg/cap/year)":2.406898},
      {"year": "1995", "Food availibility per capita (kg/cap/year)": 169.110664,"Production Quantity per capita (kg/cap/year)":127.535479,"Exports (all) per capita (kg/cap/year)":0.015417,"Imports (all) per capita (kg/cap/year)":61.262911,"Total Food Aid per capita (kg/cap/year)":3.092856},
      {"year": "1996", "Food availibility per capita (kg/cap/year)": 167.338696,"Production Quantity per capita (kg/cap/year)":201.394721,"Exports (all) per capita (kg/cap/year)":5.540799,"Imports (all) per capita (kg/cap/year)":13.385312,"Total Food Aid per capita (kg/cap/year)":8.815025},
      {"year": "1997", "Food availibility per capita (kg/cap/year)": 161.098573,"Production Quantity per capita (kg/cap/year)":147.558141,"Exports (all) per capita (kg/cap/year)":5.333603,"Imports (all) per capita (kg/cap/year)":41.299866,"Total Food Aid per capita (kg/cap/year)":1.294078},
      {"year": "1998", "Food availibility per capita (kg/cap/year)": 141.595014,"Production Quantity per capita (kg/cap/year)":114.156290,"Exports (all) per capita (kg/cap/year)":0.036865,"Imports (all) per capita (kg/cap/year)":39.179070,"Total Food Aid per capita (kg/cap/year)":2.460516},
      {"year": "1999", "Food availibility per capita (kg/cap/year)": 146.469081,"Production Quantity per capita (kg/cap/year)":137.027504,"Exports (all) per capita (kg/cap/year)":5.239133,"Imports (all) per capita (kg/cap/year)":42.109792,"Total Food Aid per capita (kg/cap/year)":3.724844	},
      {"year": "2000", "Food availibility per capita (kg/cap/year)": 134.764539,"Production Quantity per capita (kg/cap/year)":148.433149,"Exports (all) per capita (kg/cap/year)":4.910802,"Imports (all) per capita (kg/cap/year)":7.486430,"Total Food Aid per capita (kg/cap/year)":5.198604},
      {"year": "2001", "Food availibility per capita (kg/cap/year)": 139.710353,"Production Quantity per capita (kg/cap/year)":124.992656,"Exports (all) per capita (kg/cap/year)":2.422000,"Imports (all) per capita (kg/cap/year)":26.658533,"Total Food Aid per capita (kg/cap/year)":4.614148},
      {"year": "2002", "Food availibility per capita (kg/cap/year)": 125.957625,"Production Quantity per capita (kg/cap/year)":103.659683,"Exports (all) per capita (kg/cap/year)":0.963466,"Imports (all) per capita (kg/cap/year)":35.681965,"Total Food Aid per capita (kg/cap/year)":7.087426},
      {"year": "2003", "Food availibility per capita (kg/cap/year)": 138.124819,"Production Quantity per capita (kg/cap/year)":157.277777,"Exports (all) per capita (kg/cap/year)":9.191665,"Imports (all) per capita (kg/cap/year)":26.906714,"Total Food Aid per capita (kg/cap/year)":14.694408},
      {"year": "2004", "Food availibility per capita (kg/cap/year)": 137.397087,"Production Quantity per capita (kg/cap/year)":155.191166,"Exports (all) per capita (kg/cap/year)":13.593614,"Imports (all) per capita (kg/cap/year)":11.245455,"Total Food Aid per capita (kg/cap/year)":9.058024},
      {"year": "2005", "Food availibility per capita (kg/cap/year)": 135.369203,"Production Quantity per capita (kg/cap/year)":127.545889,"Exports (all) per capita (kg/cap/year)":0.891188,"Imports (all) per capita (kg/cap/year)":20.886628,"Total Food Aid per capita (kg/cap/year)":13.864948},
      {"year": "2006", "Food availibility per capita (kg/cap/year)": 136.983614,"Production Quantity per capita (kg/cap/year)":171.415080,"Exports (all) per capita (kg/cap/year)":10.315675,"Imports (all) per capita (kg/cap/year)":7.438283,"Total Food Aid per capita (kg/cap/year)":10.200834},
      {"year": "2007", "Food availibility per capita (kg/cap/year)": 137.636198,"Production Quantity per capita (kg/cap/year)":160.885880,"Exports (all) per capita (kg/cap/year)":21.834650,"Imports (all) per capita (kg/cap/year)":5.246953,"Total Food Aid per capita (kg/cap/year)":3.635258},
      {"year": "2008", "Food availibility per capita (kg/cap/year)": 145.855477,"Production Quantity per capita (kg/cap/year)":174.873718,"Exports (all) per capita (kg/cap/year)":16.186318,"Imports (all) per capita (kg/cap/year)":11.620309,"Total Food Aid per capita (kg/cap/year)":2.971569},
      {"year": "2009", "Food availibility per capita (kg/cap/year)": 146.970631,"Production Quantity per capita (kg/cap/year)":209.738102,"Exports (all) per capita (kg/cap/year)":6.314069,"Imports (all) per capita (kg/cap/year)":3.376284,"Total Food Aid per capita (kg/cap/year)":1.650769},
      {"year": "2010", "Food availibility per capita (kg/cap/year)": 150.969883,"Production Quantity per capita (kg/cap/year)":273.465065,"Exports (all) per capita (kg/cap/year)":19.126000,"Imports (all) per capita (kg/cap/year)":2.884853,"Total Food Aid per capita (kg/cap/year)":1.453386},
      {"year": "2011", "Food availibility per capita (kg/cap/year)": 152.932415,"Production Quantity per capita (kg/cap/year)":288.199460,"Exports (all) per capita (kg/cap/year)":52.715415,"Imports (all) per capita (kg/cap/year)":3.997020,"Total Food Aid per capita (kg/cap/year)":0.335174},
      {"year": "2012", "Food availibility per capita (kg/cap/year)": 148.678663,"Production Quantity per capita (kg/cap/year)":268.148804,"Exports (all) per capita (kg/cap/year)":51.162505,"Imports (all) per capita (kg/cap/year)":1.934589,"Total Food Aid per capita (kg/cap/year)":0.291001},
      {"year": "2013", "Food availibility per capita (kg/cap/year)": 147.036403,"Production Quantity per capita (kg/cap/year)":203.465030,"Exports (all) per capita (kg/cap/year)":51.162505,"Imports (all) per capita (kg/cap/year)":1.934589,"Total Food Aid per capita (kg/cap/year)":0.291001},
    ]

Events = [{"start":"1999","end":"1999","Legend":"Food availibility per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Total Food Aid per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Imports (all) per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Production Quantity per capita(kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Exports (all) per capita (kg/cap/year)"},{"start": "1980","end": "1990","Legend": "Challenges against Kenneth Kaunda regime (single party)"},{"start":"1991","end":"1992","Legend":"First multi-party elections"},{"start":"1992","end":"2013","Legend":"Liberal policy"},{"start":"2002","end":"2003","Legend":"Famine"}]


Zambia = alt.pd.DataFrame(Zambia)
Events = alt.pd.DataFrame(Events)


line1 = alt.Chart(Zambia).mark_line(color='green').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Food availibility per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line2 = alt.Chart(Zambia).mark_line(color='pink').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Production Quantity per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line3 = alt.Chart(Zambia).mark_line(color='orange').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Exports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line4 = alt.Chart(Zambia).mark_line(color='yellow').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Imports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line5 = alt.Chart(Zambia).mark_line(color='brown').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y',title='Year')),
    alt.Y("Total Food Aid per capita (kg/cap/year)", axis=alt.Axis(title='kg/cap/year'))
).properties(
    width=500,
    height=300
)


rect = alt.Chart(Events).mark_rect().encode(
    x='start:T',
    x2='end:T',
    color='Legend:N'
)






rect + line1 + line2 + line3 +line4 + line5
# Out:
# alt.LayerChart(...)

# %%
Zimbabwe = [
      {"year": "1980", "Food availibility per capita (kg/cap/year)": 195.509380,"Production Quantity per capita (kg/cap/year)":277.098659,"Exports (all) per capita (kg/cap/year)":10.592508,"Imports (all) per capita (kg/cap/year)":21.341590,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1981", "Food availibility per capita (kg/cap/year)": 184.402859,"Production Quantity per capita (kg/cap/year)":441.157003,"Exports (all) per capita (kg/cap/year)":32.337129,"Imports (all) per capita (kg/cap/year)":3.764456,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1982", "Food availibility per capita (kg/cap/year)": 180.042037,"Production Quantity per capita (kg/cap/year)":284.092789,"Exports (all) per capita (kg/cap/year)":45.280635,"Imports (all) per capita (kg/cap/year)":1.441143,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1983", "Food availibility per capita (kg/cap/year)": 173.834230,"Production Quantity per capita (kg/cap/year)":150.695514,"Exports (all) per capita (kg/cap/year)":60.884662,"Imports (all) per capita (kg/cap/year)":9.128509,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1984", "Food availibility per capita (kg/cap/year)": 175.072583,"Production Quantity per capita (kg/cap/year)":170.948481,"Exports (all) per capita (kg/cap/year)":0.361932,"Imports (all) per capita (kg/cap/year)":43.515663,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1985", "Food availibility per capita (kg/cap/year)": 166.554088,"Production Quantity per capita (kg/cap/year)":390.636389,"Exports (all) per capita (kg/cap/year)":21.366234,"Imports (all) per capita (kg/cap/year)":17.274306,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1986", "Food availibility per capita (kg/cap/year)": 166.572215,"Production Quantity per capita (kg/cap/year)":341.501288,"Exports (all) per capita (kg/cap/year)":47.743961,"Imports (all) per capita (kg/cap/year)":5.909783,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1987", "Food availibility per capita (kg/cap/year)": 164.461898,"Production Quantity per capita (kg/cap/year)":162.555190,"Exports (all) per capita (kg/cap/year)":42.567423,"Imports (all) per capita (kg/cap/year)":4.952326,"Total Food Aid per capita (kg/cap/year)":0.0},
      {"year": "1988", "Food availibility per capita (kg/cap/year)": 161.380330,"Production Quantity per capita (kg/cap/year)":317.052553,"Exports (all) per capita (kg/cap/year)":41.609785,"Imports (all) per capita (kg/cap/year)":8.526188,"Total Food Aid per capita (kg/cap/year)":0.473611},
      {"year": "1989", "Food availibility per capita (kg/cap/year)": 163.137636,"Production Quantity per capita (kg/cap/year)":255.476759,"Exports (all) per capita (kg/cap/year)":21.923926,"Imports (all) per capita (kg/cap/year)":5.113580,"Total Food Aid per capita (kg/cap/year)":1.292264},
      {"year": "1990", "Food availibility per capita (kg/cap/year)": 191.616452,"Production Quantity per capita (kg/cap/year)":250.925446,"Exports (all) per capita (kg/cap/year)":50.650621,"Imports (all) per capita (kg/cap/year)":7.740723,"Total Food Aid per capita (kg/cap/year)":1.336079},
      {"year": "1991", "Food availibility per capita (kg/cap/year)": 165.266202,"Production Quantity per capita (kg/cap/year)":196.096491,"Exports (all) per capita (kg/cap/year)":23.472201,"Imports (all) per capita (kg/cap/year)":9.442603,"Total Food Aid per capita (kg/cap/year)":1.857237},
      {"year": "1992", "Food availibility per capita (kg/cap/year)": 156.248688,"Production Quantity per capita (kg/cap/year)":48.396910,"Exports (all) per capita (kg/cap/year)":0.173605,"Imports (all) per capita (kg/cap/year)":191.879629,"Total Food Aid per capita (kg/cap/year)":53.218037},
      {"year": "1993", "Food availibility per capita (kg/cap/year)": 162.229581,"Production Quantity per capita (kg/cap/year)":227.296961,"Exports (all) per capita (kg/cap/year)":35.242329,"Imports (all) per capita (kg/cap/year)":41.513517,"Total Food Aid per capita (kg/cap/year)":53.907091},
      {"year": "1994", "Food availibility per capita (kg/cap/year)": 164.822142,"Production Quantity per capita (kg/cap/year)":253.146808,"Exports (all) per capita (kg/cap/year)":13.153936,"Imports (all) per capita (kg/cap/year)":14.493488,"Total Food Aid per capita (kg/cap/year)":2.124509},
      {"year": "1995", "Food availibility per capita (kg/cap/year)": 159.016292,"Production Quantity per capita (kg/cap/year)":88.761489,"Exports (all) per capita (kg/cap/year)":0.131725,"Imports (all) per capita (kg/cap/year)":61.386132,"Total Food Aid per capita (kg/cap/year)":1.192906},
      {"year": "1996", "Food availibility per capita (kg/cap/year)": 164.413141,"Production Quantity per capita (kg/cap/year)":268.614763,"Exports (all) per capita (kg/cap/year)":25.097562,"Imports (all) per capita (kg/cap/year)":14.628154,"Total Food Aid per capita (kg/cap/year)":1.115166},
      {"year": "1997", "Food availibility per capita (kg/cap/year)": 155.971069,"Production Quantity per capita (kg/cap/year)":229.667609,"Exports (all) per capita (kg/cap/year)":9.133909,"Imports (all) per capita (kg/cap/year)":16.608803,"Total Food Aid per capita (kg/cap/year)":0.011164},
      {"year": "1998", "Food availibility per capita (kg/cap/year)": 157.807848,"Production Quantity per capita (kg/cap/year)":160.542672,"Exports (all) per capita (kg/cap/year)":4.095152,"Imports (all) per capita (kg/cap/year)":38.325116,"Total Food Aid per capita (kg/cap/year)":5.047498},
      {"year": "1999", "Food availibility per capita (kg/cap/year)": 154.413555,"Production Quantity per capita (kg/cap/year)":167.120397,"Exports (all) per capita (kg/cap/year)":2.376595,"Imports (all) per capita (kg/cap/year)":27.852088,"Total Food Aid per capita (kg/cap/year)":2.837276},
      {"year": "2000", "Food availibility per capita (kg/cap/year)": 153.414821,"Production Quantity per capita (kg/cap/year)":208.890073,"Exports (all) per capita (kg/cap/year)":0.019710,"Imports (all) per capita (kg/cap/year)":11.021564,"Total Food Aid per capita (kg/cap/year)":1.390741},
      {"year": "2001", "Food availibility per capita (kg/cap/year)": 153.032837,"Production Quantity per capita (kg/cap/year)":162.959716,"Exports (all) per capita (kg/cap/year)":0.000288,"Imports (all) per capita (kg/cap/year)":36.241508,"Total Food Aid per capita (kg/cap/year)":0.002416},
      {"year": "2002", "Food availibility per capita (kg/cap/year)": 152.664677,"Production Quantity per capita (kg/cap/year)":66.801906,"Exports (all) per capita (kg/cap/year)":0.187419,"Imports (all) per capita (kg/cap/year)":94.186445,"Total Food Aid per capita (kg/cap/year)":22.465156},
      {"year": "2003", "Food availibility per capita (kg/cap/year)": 154.186172,"Production Quantity per capita (kg/cap/year)":101.097648,"Exports (all) per capita (kg/cap/year)":0.163895,"Imports (all) per capita (kg/cap/year)":69.517752,"Total Food Aid per capita (kg/cap/year)":32.012662},
      {"year": "2004", "Food availibility per capita (kg/cap/year)": 203.442918,"Production Quantity per capita (kg/cap/year)":168.689003,"Exports (all) per capita (kg/cap/year)":0.034663,"Imports (all) per capita (kg/cap/year)":67.476513,"Total Food Aid per capita (kg/cap/year)":22.793253},
      {"year": "2005", "Food availibility per capita (kg/cap/year)": 155.335290,"Production Quantity per capita (kg/cap/year)":99.236445,"Exports (all) per capita (kg/cap/year)":0.010412,"Imports (all) per capita (kg/cap/year)":64.998852,"Total Food Aid per capita (kg/cap/year)":6.645581},
      {"year": "2006", "Food availibility per capita (kg/cap/year)": 162.032954,"Production Quantity per capita (kg/cap/year)":162.720893,"Exports (all) per capita (kg/cap/year)":0.214076,"Imports (all) per capita (kg/cap/year)":34.844144,"Total Food Aid per capita (kg/cap/year)":12.254623},
      {"year": "2007", "Food availibility per capita (kg/cap/year)": 165.628805,"Production Quantity per capita (kg/cap/year)":108.290847,"Exports (all) per capita (kg/cap/year)":0.000422,"Imports (all) per capita (kg/cap/year)":63.429329,"Total Food Aid per capita (kg/cap/year)":14.731434},
      {"year": "2008", "Food availibility per capita (kg/cap/year)": 153.700079,"Production Quantity per capita (kg/cap/year)":74.895878,"Exports (all) per capita (kg/cap/year)":0.000396,"Imports (all) per capita (kg/cap/year)":80.948491,"Total Food Aid per capita (kg/cap/year)":32.483310},
      {"year": "2009", "Food availibility per capita (kg/cap/year)": 141.317483,"Production Quantity per capita (kg/cap/year)":134.498252,"Exports (all) per capita (kg/cap/year)":0.001154,"Imports (all) per capita (kg/cap/year)":46.373575,"Total Food Aid per capita (kg/cap/year)":23.016895},
      {"year": "2010", "Food availibility per capita (kg/cap/year)": 136.990970,"Production Quantity per capita (kg/cap/year)":137.107037,"Exports (all) per capita (kg/cap/year)":0.001145,"Imports (all) per capita (kg/cap/year)":29.493594,"Total Food Aid per capita (kg/cap/year)":7.819579},
      {"year": "2011", "Food availibility per capita (kg/cap/year)": 139.933312,"Production Quantity per capita (kg/cap/year)":138.424832,"Exports (all) per capita (kg/cap/year)":0.001129,"Imports (all) per capita (kg/cap/year)":50.350006,"Total Food Aid per capita (kg/cap/year)":4.502947},
      {"year": "2012", "Food availibility per capita (kg/cap/year)": 142.318797,"Production Quantity per capita (kg/cap/year)":96.503586,"Exports (all) per capita (kg/cap/year)":0.001107,"Imports (all) per capita (kg/cap/year)":47.807283,"Total Food Aid per capita (kg/cap/year)":3.268701},
      {"year": "2013", "Food availibility per capita (kg/cap/year)": 143.292102,"Production Quantity per capita (kg/cap/year)":75.067527,"Exports (all) per capita (kg/cap/year)":0.001107,"Imports (all) per capita (kg/cap/year)":47.807283,"Total Food Aid per capita (kg/cap/year)":3.268701},
    ]

Events = [{"start":"1999","end":"1999","Legend":"Food availibility per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Total Food Aid per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Imports (all) per capita (kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Production Quantity per capita(kg/cap/year)"},{"start":"1997","end":"1997","Legend":"Exports (all) per capita (kg/cap/year)"},{"start": "1980","end": "1981","Legend": "Proclamation of independence"},{"start":"1987","end":"2008","Legend":"Authoritarian regime"},{"start":"2008","end":"2009","Legend":"Majority democratic in the assembly"},{"start":"2009","end":"2010","Legend":"Inflationary explosion"}]


Zimbabwe = alt.pd.DataFrame(Zimbabwe)
Events = alt.pd.DataFrame(Events)


line1 = alt.Chart(Zimbabwe).mark_line(color='red').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Food availibility per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line2 = alt.Chart(Zimbabwe).mark_line(color='pink').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Production Quantity per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line3 = alt.Chart(Zimbabwe).mark_line(color='orange').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Exports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line4 = alt.Chart(Zimbabwe).mark_line(color='aqua').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y')),
    y='Imports (all) per capita (kg/cap/year)'
).properties(
    width=500,
    height=300
)

line5 = alt.Chart(Zimbabwe).mark_line(color='brown').encode(
    alt.X('year:T', axis=alt.Axis(format='%Y',title='Year')),
    alt.Y("Total Food Aid per capita (kg/cap/year)", axis=alt.Axis(title='kg/cap/year'))
).properties(
    width=500,
    height=300
)


rect = alt.Chart(Events).mark_rect().encode(
    x='start:T',
    x2='end:T',
    color='Legend:N'
)






rect + line1 + line2 + line3 +line4 + line5
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Sources used to study the principal political events since 1980 in these countries :
# https://perspective.usherbrooke.ca/bilan/BMEncyclopedie/BMEphemeride.jsp
#
# https://fr.wikipedia.org/wiki/Wikip%C3%A9dia:Accueil_principal
